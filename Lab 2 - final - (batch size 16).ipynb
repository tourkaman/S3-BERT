# %% [markdown]
# # Setup

# %%
from torch import nn
from torch import Tensor
from torch.utils.data import DataLoader

from sentence_transformers import SentenceTransformer, InputExample
from sentence_transformers.models import Transformer, Pooling
from sentence_transformers.losses import CosineSimilarityLoss
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator, SimilarityFunction

# For debugging
# from scipy.stats import spearmanr, pearsonr
# from sklearn.metrics.pairwise import paired_cosine_distances, paired_euclidean_distances, paired_manhattan_distances

# %% [markdown]
# ### Settings

# %%
# Data and training
batch_size = 16  # {16, 32}

# Training
epochs = 1
warmup_steps = 100

# %% [markdown]
# # Data

# %% [markdown]
# Using the official STS Benchmark dataset:
# https://ixa2.si.ehu.eus/stswiki/index.php/STSbenchmark

# %% [markdown]
# Information about the train/dev/test datasets are available under `data/stsbenchmark/readme.txt`

# %% [markdown]
# ## Data loading and cleanup

# %% [markdown]
# There seem to be some rows with 7 columns and some with 9 columns (proabably due to additional licensing information), and so we'll try to make sure we don't miss the 3 important columns that we need: Score, Sentence 1, and Sentence 2.

# %%
train_csv = 'data/stsbenchmark/sts-train.csv'
dev_csv   = 'data/stsbenchmark/sts-dev.csv'
test_csv  = 'data/stsbenchmark/sts-test.csv'

# %% [markdown]
# ### Training set

# %%
with open(train_csv) as f:
    lines = f.readlines()
    lines = [l.strip() for l in lines]

# %%
# Should be 5749
len(lines)
# Out:
# 5749

# %%
rows = [l.split('\t') for l in lines]

# %%
row_type_counts = {}

for row in rows:
    if len(row) not in row_type_counts.keys():
        row_type_counts[len(row)] = 1
    else:
        row_type_counts[len(row)] += 1

row_type_counts
# Out:
# {7: 5552, 9: 197}

# %% [markdown]
# Assuming that the data is clean enough and the rows with 7 columns are all correctly filled, we will just quickly check the relevant columns of those with 9 fields, just to make sure our data is clean.

# %%
for row in rows:
    if len(row) == 9:
        print(f'{row[4][:10]}  |  {row[5][:10]}  |  {row[6][:10]}')
# Out:
# 4  |  Driver bac  |  Driver bac
# 5  |  Spain Prin  |  Spain prin
# 5  |  Senate con  |  Senate app
# 5  |  U.N. right  |  UN Rights
# 5  |  US Senate   |  Senate con
# 5  |  Syrian Reb  |  Syrian reb
# 3  |  Mayawati d  |  Mayawati d
# 4  |  Uganda's p  |  Uganda's p
# 5  |  Rocks, Tea  |  Rocks, tea
# 5  |  Boston bom  |  Boston bom
# 5  |  Six dead i  |  6 killed i
# 5  |  China army  |  China army
# 4  |  Silvio Ber  |  Silvio Ber
# 5  |  Two killed  |  Two killed
# 5  |  Russia war  |  Russia war
# 4  |  Hosni Muba  |  Mubarak re
# 4  |  Egypt prot  |  Egypt prot
# 5  |  Couple mar  |  Couple get
# 4  |  Qatar's em  |  Qatari emi
# 3  |  Philippine  |  Philippine
# 4  |  Egypt brac  |  Egypt brac
# 4  |  Red Sox Be  |  Red Sox be
# 4  |  China land  |  China land
# 4  |  Ukrainian   |  Ukraine's
# 5  |  Venezuela   |  Venezuela
# 5  |  North Kore  |  North Kore
# 4  |  Captain of  |  Captain of
# 3  |  Cars, driv  |  Cars plung
# 5  |  Death toll  |  Death toll
# 4  |  Communist   |  Communist
# 3  |  Egypt's Mo  |  Egypt's Mo
# 5  |  Iran Nucle  |  Iran nucle
# 3  |  Thai army   |  Thailand's
# 4  |  Woman dies  |  Woman dies
# 4  |  Nobel auth  |  Nobel Priz
# 5  |  Over 100 d  |  At least 1
# 4  |  First post  |  India's fi
# 3  |  Israel agr  |  Israel agr
# 3  |  Quake of 6  |  Earthquake
# 4  |  British st  |  British st
# 5  |  What makes  |  What makes
# 4  |  White diam  |  White diam
# 3  |  Chinese sa  |  Malaysia:
# 5  |  Hamas Urge  |  Hamas call
# 3  |  U.S. and R  |  China welc
# 4  |  PSNI faile  |  13:23 PSNI
# 5  |  Stocks edg  |  Stocks edg
# 4  |  Police hel  |  Police hel
# 4  |  US ups pre  |  US, UN up
# 4  |  Australian  |  Australian
# 1  |  Mandela's   |  Mandela's
# 4  |  Philippe b  |  Philippe a
# 4  |  India anti  |  India's An
# 5  |  Spain appr  |  Spanish go
# 2  |  Obama orde  |  UN urges S
# 5  |  German amb  |  Shots fire
# 2  |  Ukraine's   |  Ukraine's
# 3  |  Oklahoma e  |  Okla. inma
# 5  |  Napolitano  |  Italian Pr
# 4  |  UN court c  |  UN War Cri
# 4  |  Saudi man   |  Saudi Man
# 5  |  North Kore  |  North Kore
# 3  |  Thai prote  |  Thai prote
# 3  |  Egypt impo  |  Egypt anno
# 4  |  Rallies de  |  Across US,
# 3  |  UN warns o  |  UNICEF cal
# 4  |  Hagel, Dem  |  Hagel lame
# 3  |  Sony to se  |  Sony to ax
# 2  |  Man kills   |  Police: Gu
# 2  |  N. Korea D  |  North Kore
# 1  |  Search lea  |  Searchers
# 1  |  Mandela re  |  Mandela's
# 4  |  Ukrainian   |  Ukraine ri
# 2  |  Obama mull  |  Obama urge
# 4  |  Syria's PM  |  Syrian pri
# 3  |  Jordan ele  |  Jordan ele
# 0  |  At least 1  |  More than
# 3  |  Police sur  |  Peaceful a
# 1  |  George Zim  |  George Zim
# 3  |  Ten rescue  |  Six rescue
# 5  |  Mandela sp  |  Mandela in
# 2  |  One killed  |  Egypt: Pro
# 2  |  Saudi Wome  |  Saudi wome
# 1  |  Russian pa  |  President
# 2  |  Nelson Man  |  Nelson Man
# 1  |  World stoc  |  Fed expect
# 1  |  No winners  |  The impact
# 3  |  World Cup   |  Worker die
# 1  |  Tata Nano   |  How does w
# 3  |  Greece rea  |  Debt inspe
# 5  |  Murray end  |  Murray win
# 0  |  Malaysia A  |  US: Russia
# 2  |  US to Dete  |  What we kn
# 0  |  The covert  |  New major
# 2  |  Russia's P  |  Kremlin: P
# 3  |  Senior CPC  |  North Kore
# 1  |  Turkey unr  |  Turkish PM
# 5  |  Pope calls  |  Pope urges
# 2  |  Singapore   |  Singapore
# 5  |  Who Is Jih  |  Who was 'J
# 2  |  Headlines   |  Headlines
# 4  |  US Attorne  |  US Attorne
# 5  |  U.S., EU W  |  U.S., EU B
# 1  |  Top Asian   |  Top Asian
# 2  |  How the Do  |  How the Do
# 4  |  Hajj to go  |  Hajj to go
# 3  |  US House R  |  US House R
# 3  |  Top Asian   |  Top Asian
# 1  |  Singapore   |  Singapore
# 1  |  China trea  |  China trea
# 5  |  US Attorne  |  Attorney G
# 3  |  Headlines   |  Headlines
# 4  |  China on h  |  China issu
# 3  |  Saudi-led   |  Saudi airs
# 3  |  Mali hunts  |  Militants
# 1  |  7.3 magnit  |  6.6-magnit
# 4  |  Tokyo shar  |  Tokyo shar
# 1  |  Iran's par  |  Iran hardl
# 5  |  Hawaii pre  |  Hawaii bra
# 2  |  Iraq bombi  |  Iraq suici
# 3  |  Sierra Leo  |  Sierra Leo
# 4  |  Tokyo shar  |  Tokyo shar
# 0  |  4 killed,   |  Two killed
# 3  |  More than   |  Over 2,000
# 4  |  Lewis Hami  |  Lewis Hami
# 2  |  UN Securit  |  UN Securit
# 1  |  Israeli fo  |  Israeli se
# 0  |  4 dead, 3   |  2 dead, 8
# 2  |  Markets Li  |  Markets Li
# 2  |  Palestinia  |  Palestinia
# 4  |  Suspected   |  Suspected
# 2  |  The end of  |  UK 'concer
# 2  |  Russian wa  |  Russian ro
# 1  |  CCTV of gu  |  19 killed
# 0  |  Live Blog:  |  Live Blog:
# 2  |  Nigeria Vo  |  Guineans G
# 2  |  Prince Wil  |  Prince Wil
# 2  |  Micronesia  |  Vice Presi
# 3  |  Islamic St  |  Islamic St
# 2  |  Iran ends   |  Iran, Taji
# 1  |  Teenager t  |  Texas hosp
# 1  |  Texas sues  |  Turkey 'ex
# 2  |  New US San  |  China disa
# 0  |  5 killed i  |  38 IS mili
# 2  |  Deadly Bla  |  12 Dead, D
# 3  |  Greece bai  |  Greece con
# 1  |  Rooney hel  |  West Ham b
# 1  |  Hard-line   |  Israeli le
# 2  |  Backstage   |  Mixed Prog
# 1  |  Egypt: IPI  |  Egypt sent
# 1  |  occupied P  |  occupied P
# 0  |  Libya: UN   |  India's to
# 2  |  Taiwan coa  |  Chinese mi
# 1  |  Burundi po  |  Montenegri
# 3  |  Nepal eart  |  Death toll
# 1  |  Ashya's Pa  |  Ashya King
# 1  |  Nigeria ad  |  US ramps u
# 1  |  Thousands   |  Thousands
# 0  |  Kranjcar l  |  Harry Kane
# 0  |  Oscar Pist  |  'Bookkeepe
# 2  |  Pro-Palest  |  Pro-Palest
# 1  |  Benzema fa  |  Menendez f
# 2  |  All 224 de  |  Heat flash
# 0  |  Govt. to h  |  Cameron to
# 0  |  Li Na to a  |  US Senator
# 1  |  Gunners fi  |  EPL clubs
# 1  |  Iranian Pr  |  Iran arres
# 1  |  Boko Haram  |  Press awas
# 1  |  South Kore  |  South Kore
# 0  |  Plane Cras  |  Tour De Fr
# 0  |  Obama quer  |  Spanish bu
# 0  |  China's ge  |  China keep
# 0  |  Hezbollah   |  Belarus ti
# 1  |  South Kore  |  South Kore
# 0  |  Obama call  |  Obama vows
# 1  |  U.S. milit  |  Observator
# 0  |  Who abando  |  Police aba
# 2  |  North Kore  |  N Korea hi
# 2  |  Hong Kong   |  Hong Kong
# 0  |  Ebola UK:   |  UK says in
# 1  |  UK Leader   |  Why Cyprus
# 0  |  N. Korea a  |  Johor crow
# 0  |  Iran, a la  |  Iran reite
# 0  |  Taiwan's p  |  Poland pre
# 0  |  Two Palest  |  Palestinia
# 0  |  Thomas Coo  |  University
# 0  |  Narendra M  |  PM Narendr
# 1  |  UN chief w  |  UN chief c
# 0  |  Pakistan e  |  Pakistan p
# 0  |  Two Austra  |  Permalink
# 2  |  France shu  |  Security t
# 2  |  Russian pl  |  Pilot kill
# 0  |  Severe Gal  |  Merkel ple
# 0  |  Dozens of   |  Egyptian b
# 0  |  President   |  President
# 0  |  China, Ind  |  China Scra
# 0  |  Putin spok  |  The Latest

# %% [markdown]
# Everything seems OK. Let's just check the first 20 rows with 7 columns also.

# %%
for row in rows[:20]:
    if len(row) == 7:
        print(f'{row[4][:10]}  |  {row[5][:10]}  |  {row[6][:10]}')
# Out:
# 5.000  |  A plane is  |  An air pla
# 3.800  |  A man is p  |  A man is p
# 3.800  |  A man is s  |  A man is s
# 2.600  |  Three men   |  Two men ar
# 4.250  |  A man is p  |  A man seat
# 4.250  |  Some men a  |  Two men ar
# 0.500  |  A man is s  |  A man is s
# 1.600  |  The man is  |  The man is
# 2.200  |  A man is p  |  A woman is
# 5.000  |  A person i  |  A person t
# 4.200  |  The man hi  |  The man sp
# 4.600  |  A woman pi  |  A woman pi
# 3.867  |  A man is p  |  A man is p
# 4.667  |  A person i  |  Someone is
# 1.667  |  A man is r  |  A panda do
# 3.750  |  A dog is t  |  A dog is t
# 5.000  |  The polar   |  A polar be
# 0.500  |  A woman is  |  A woman is
# 3.800  |  A cat is r  |  A cat is r
# 5.000  |  The man is  |  A man is r

# %% [markdown]
# All good!
#
# Making SentenceTransformer-specific DataLoaders out of them then.

# %%
examples = []

for row in rows:
    examples.append(
        InputExample(
            texts=[row[5].strip(), row[6].strip()],
            label=float(row[4])))

train_dl = DataLoader(examples, shuffle=True, batch_size=batch_size)

# %%
# Should be 5749
len(examples)
# Out:
# 5749

# %% [markdown]
# ### Development set

# %%
with open(dev_csv) as f:
    lines = f.readlines()
    lines = [l.strip() for l in lines]

# %%
# Should be 1500
len(lines)
# Out:
# 1500

# %%
rows = [l.split('\t') for l in lines]

# %%
row_type_counts = {}

for row in rows:
    if len(row) not in row_type_counts.keys():
        row_type_counts[len(row)] = 1
    else:
        row_type_counts[len(row)] += 1

row_type_counts
# Out:
# {7: 1478, 9: 22}

# %% [markdown]
# Assuming that the data is clean enough and the rows with 7 columns are all correctly filled, we will just quickly check the relevant columns of those with 9 fields, just to make sure our data is clean.

# %%
for row in rows:
    if len(row) == 9:
        print(f'{row[4][:10]}  |  {row[5][:10]}  |  {row[6][:10]}')
# Out:
# 5  |  US Supreme  |  High court
# 4  |  Euro crisi  |  Eurozone d
# 4  |  Treasury p  |  Treasury p
# 3  |  EU Ministe  |  EU Ministe
# 5  |  Chinese lu  |  China land
# 2  |  Boy, 14, a  |  Two teenag
# 3  |  Protests a  |  Zimmerman
# 3  |  Maldives b  |  Crisis-hit
# 1  |  Obama, Hol  |  Hollande a
# 5  |  Iran, IAEA  |  Iran, IAEA
# 2  |  Bombings k  |  Bombings k
# 2  |  10 Things   |  10 Things
# 2  |  New UN pea  |  UN takes o
# 5  |  Oil falls   |  Oil prices
# 3  |  Israeli fo  |  Israeli fo
# 3  |  Israeli po  |  Israel Pol
# 0  |  3 killed,   |  Five kille
# 2  |  Scientists  |  Has Nasa d
# 0  |  Pranab str  |  WTO: India
# 2  |  Volkswagen  |  Volkswagen
# 0  |  Obama is r  |  Obama wait
# 0  |  New video   |  New York p

# %% [markdown]
# Everything seems OK. Let's just check the first 20 rows with 7 columns also.

# %%
for row in rows:
    if len(row) == 7:
        print(f'{row[4][:10]}  |  {row[5][:10]}  |  {row[6][:10]}')
# Out:
# 5.000  |  A man with  |  A man wear
# 4.750  |  A young ch  |  A child is
# 5.000  |  A man is f  |  The man is
# 2.400  |  A woman is  |  A man is p
# 2.750  |  A woman is  |  A man is p
# 2.615  |  A woman is  |  A man is c
# 5.000  |  A man is e  |  The man is
# 2.333  |  A woman is  |  A woman is
# 3.750  |  Three men   |  Three men
# 5.000  |  A woman pe  |  A woman is
# 3.200  |  People are  |  Men are pl
# 1.583  |  A man is p  |  A man is p
# 5.000  |  The cougar  |  A cougar i
# 5.000  |  The man cu  |  A man chop
# 4.909  |  The man is  |  A man is p
# 0.800  |  A man is f  |  A woman is
# 2.400  |  The girl s  |  The lady s
# 5.000  |  A man is c  |  A man clim
# 4.000  |  Kittens ar  |  Kittens ar
# 0.636  |  A man is s  |  A man is s
# 3.000  |  A woman is  |  A woman is
# 1.714  |  A man is p  |  A man is p
# 3.200  |  An animal   |  An animal
# 2.167  |  A man is p  |  A man is p
# 1.000  |  A man is p  |  A man is p
# 1.917  |  A girl is   |  A girl is
# 4.250  |  A man is l  |  A man is l
# 3.000  |  An animal   |  A slow lor
# 1.000  |  A woman is  |  A woman is
# 0.600  |  A man is c  |  A woman is
# 2.600  |  The lady c  |  The man is
# 5.000  |  A band is   |  A band is
# 4.600  |  Elephants   |  A herd of
# 5.000  |  A man is p  |  A man play
# 4.800  |  A man sitt  |  A man sitt
# 3.800  |  A puppy pl  |  The dog is
# 5.000  |  A man play  |  A man is p
# 5.000  |  A man play  |  A man is p
# 4.200  |  A man is e  |  A man is e
# 1.400  |  A man is p  |  A man is p
# 3.600  |  A toddler   |  A little g
# 2.800  |  A plane is  |  A animated
# 1.600  |  A panda is  |  A man is c
# 3.000  |  Kids are d  |  Some peopl
# 1.400  |  A man play  |  A man play
# 0.250  |  A woman is  |  A woman is
# 0.250  |  A woman is  |  A man is p
# 0.000  |  The man is  |  A woman is
# 4.000  |  A man is d  |  Someone is
# 4.500  |  A man is f  |  A man is a
# 0.500  |  Two little  |  A little g
# 3.800  |  Someone is  |  Someone is
# 4.800  |  The woman   |  The lady b
# 5.000  |  A woman pu  |  A woman is
# 0.250  |  A man is t  |  A man is s
# 1.200  |  A man is p  |  A man is p
# 0.600  |  A man is p  |  A man is e
# 0.800  |  A man is j  |  A man is c
# 3.800  |  A man is p  |  A guy is p
# 0.000  |  A young ma  |  A woman is
# 3.500  |  A woman is  |  A woman is
# 4.500  |  Someone is  |  Someone is
# 2.800  |  A slow lor  |  A animal i
# 3.800  |  A little b  |  A boy is v
# 3.800  |  A woman is  |  A woman is
# 0.000  |  A man is m  |  A woman is
# 4.000  |  A man play  |  A person i
# 4.250  |  A rabbit i  |  A bunny is
# 2.812  |  A plane ri  |  An airplan
# 4.250  |  A man shoo  |  A man with
# 3.000  |  A man play  |  The man sa
# 1.000  |  A guy is p  |  A man is p
# 3.750  |  One man is  |  A man brea
# 0.000  |  A man is t  |  A man is w
# 0.400  |  The woman   |  A woman is
# 4.000  |  A chef is   |  A chef pre
# 2.800  |  The man ta  |  A teenager
# 3.750  |  A turtle w  |  A large tu
# 1.154  |  The lady c  |  The lady s
# 2.750  |  Five kitte  |  Kittens ar
# 2.800  |  A woman is  |  A woman is
# 0.000  |  A man play  |  A woman is
# 0.000  |  A man is p  |  A dog is b
# 3.400  |  A baby rhi  |  A baby rhi
# 5.000  |  The man us  |  A man slic
# 0.800  |  A man is c  |  A man is p
# 2.250  |  A person i  |  A woman is
# 2.750  |  A man is p  |  A man turn
# 4.500  |  A girl is   |  The girl t
# 2.600  |  Batman and  |  A helicopt
# 3.800  |  A woman po  |  An older w
# 2.800  |  A woman is  |  A woman is
# 1.600  |  The lady p  |  The lady f
# 0.000  |  A woman is  |  A man is s
# 1.333  |  The boy is  |  A band is
# 2.600  |  The cook i  |  A woman is
# 0.600  |  A woman is  |  A dog is r
# 0.000  |  A woman is  |  The woman
# 0.000  |  A cat is p  |  A man is s
# 3.000  |  A man and   |  A couple a
# 0.000  |  A woman is  |  A man is t
# 0.200  |  A man is s  |  A man is g
# 3.200  |  A girl is   |  A girl pla
# 2.000  |  A small ba  |  A boy sits
# 0.000  |  A woman is  |  A man is d
# 3.000  |  A man and   |  The man an
# 3.091  |  A child is  |  A boy is p
# 2.750  |  Men are ju  |  Men jump i
# 1.200  |  A woman is  |  A woman is
# 0.500  |  People are  |  The cricke
# 0.250  |  A person i  |  A woman is
# 0.000  |  A woman is  |  A man brea
# 0.000  |  A ballet d  |  The beaver
# 0.500  |  A man shoo  |  A man is p
# 0.000  |  The elepha  |  Two women
# 0.600  |  The man cu  |  A man is d
# 4.000  |  A woman pu  |  The woman
# 3.400  |  A woman an  |  A woman dr
# 0.000  |  A girl is   |  A onion is
# 0.000  |  A cat is o  |  A man is e
# 1.000  |  The lady s  |  A woman is
# 0.000  |  A cow is e  |  A dog is p
# 2.400  |  The man st  |  The man is
# 0.400  |  A man jump  |  A man is t
# 1.800  |  A woman is  |  A woman cu
# 2.500  |  Someone is  |  A woman st
# 0.083  |  A man is c  |  A woman pl
# 0.000  |  A man is b  |  A slow lor
# 1.000  |  A woman cu  |  A woman is
# 4.500  |  The lady c  |  A woman is
# 0.000  |  A man play  |  A woman an
# 3.600  |  A person i  |  A person i
# 5.000  |  A woman is  |  A woman is
# 5.000  |  A small do  |  A small do
# 5.000  |  The man is  |  A man is s
# 5.000  |  The man is  |  A man is s
# 3.800  |  A person i  |  A man is p
# 5.000  |  A woman is  |  A woman pu
# 2.500  |  A woman is  |  A woman is
# 3.824  |  Women are   |  Two women
# 1.600  |  A man is p  |  A woman is
# 5.000  |  A man dive  |  A man dive
# 5.000  |  The man is  |  A man is s
# 2.375  |  A man is c  |  A man is c
# 5.000  |  A man is s  |  A man slic
# 1.250  |  A man is d  |  A man is s
# 1.250  |  A man is r  |  A man is s
# 3.000  |  The man is  |  A man is t
# 2.167  |  A man is p  |  A man is p
# 1.400  |  A man is r  |  A woman is
# 4.000  |  A woman is  |  A person i
# 3.600  |  A man is e  |  A man is e
# 4.857  |  A man is p  |  A man play
# 0.400  |  The man is  |  The man is
# 0.200  |  A woman is  |  A woman is
# 1.300  |  Three men   |  Women are
# 1.200  |  A man is s  |  A man is d
# 1.200  |  A man is d  |  A man is s
# 4.400  |  A person i  |  A person i
# 1.800  |  A man is p  |  A man is p
# 1.400  |  A man is p  |  A woman is
# 0.400  |  A boy is r  |  A monkey i
# 4.400  |  The puppy   |  A puppy is
# 3.250  |  A woman is  |  The woman
# 0.778  |  A person i  |  A person i
# 2.250  |  A man is p  |  The girl i
# 2.750  |  A lion cub  |  A lion tri
# 2.000  |  A man is t  |  A guy is t
# 0.833  |  A man is p  |  A man is c
# 3.750  |  Someone is  |  The man is
# 1.800  |  A woman is  |  A woman is
# 4.333  |  The man is  |  A man is s
# 4.214  |  A target i  |  The target
# 0.000  |  A woman is  |  A man is p
# 3.400  |  A woman is  |  A person i
# 4.200  |  A man puts  |  A man is s
# 0.800  |  A man is s  |  A man is s
# 4.200  |  A person i  |  A person i
# 2.750  |  A person d  |  A man toss
# 2.200  |  The man is  |  A man is p
# 1.200  |  A woman is  |  A woman is
# 1.000  |  A woman is  |  A man is p
# 1.533  |  A man is r  |  A woman is
# 0.200  |  A man is p  |  A man is d
# 3.000  |  A tiger is  |  A tiger wa
# 3.800  |  A person p  |  A person i
# 0.750  |  A woman is  |  A woman is
# 3.000  |  A parrot i  |  A parrot i
# 0.400  |  A man is s  |  A man is d
# 3.400  |  A woman is  |  A woman li
# 3.800  |  A child ru  |  A young bo
# 1.400  |  A man is p  |  A man is p
# 3.400  |  A guy is r  |  A man is r
# 3.200  |  A dog is s  |  The dog to
# 2.333  |  A person u  |  A person i
# 0.800  |  A man is p  |  A man is g
# 0.000  |  A woman is  |  A man is s
# 3.000  |  A puppy is  |  The puppy
# 3.750  |  A person i  |  A person f
# 0.000  |  The boy is  |  The woman
# 0.000  |  A man is c  |  A woman is
# 0.000  |  A woman is  |  A man is a
# 0.500  |  A man is p  |  A woman is
# 0.500  |  A woman is  |  The woman
# 0.400  |  A man is r  |  A man is t
# 0.750  |  A man is s  |  A man seas
# 2.500  |  Someone is  |  A woman is
# 1.800  |  A man is s  |  A man is o
# 2.500  |  A monkey i  |  A monkey p
# 0.500  |  A man shap  |  A man carr
# 0.400  |  A woman is  |  A woman is
# 1.200  |  A woman is  |  A woman is
# 2.750  |  A man is s  |  A man is b
# 0.400  |  A woman is  |  A woman is
# 0.600  |  A woman is  |  The woman
# 0.800  |  A woman is  |  A woman is
# 3.000  |  A baby eat  |  A baby is
# 0.400  |  A man is s  |  A man is s
# 3.200  |  A man is p  |  A man is p
# 1.250  |  A boy is p  |  A man is s
# 5.000  |  The person  |  A person m
# 0.200  |  A woman is  |  A woman is
# 3.000  |  A person i  |  A man is f
# 1.400  |  A woman is  |  A boy is f
# 3.800  |  A person i  |  A woman is
# 2.750  |  The dog co  |  A dog is t
# 0.000  |  A woman is  |  A man is d
# 2.800  |  The lady m  |  A chef is
# 0.000  |  Someone is  |  A man is p
# 0.000  |  A woman is  |  A man is p
# 2.600  |  The animal  |  A slow lor
# 0.100  |  A baby is   |  A cat is w
# 0.000  |  A tiger cl  |  A person i
# 2.000  |  A woman is  |  Two women
# 3.750  |  The flag w  |  A flag is
# 3.100  |  The baby l  |  A baby is
# 2.692  |  A dog knoc  |  A dog push
# 4.429  |  The bird i  |  A bird is
# 5.000  |  A man play  |  A man is s
# 0.000  |  Women are   |  Two men ar
# 0.800  |  The man is  |  A man is w
# 1.333  |  A tiger is  |  A tiger at
# 0.000  |  A cat is p  |  A man is p
# 0.600  |  A cat retr  |  The cat tr
# 0.000  |  A chef is   |  A person i
# 0.000  |  A woman is  |  A young ma
# 0.000  |  A man is p  |  A woman is
# 3.400  |  Someone dr  |  A person d
# 2.200  |  The girl i  |  A woman is
# 0.000  |  The man is  |  A boy is p
# 3.6  |  A cat stan  |  A black an
# 0  |  The lamb i  |  A small bi
# 1.4  |  A bull sta  |  A brown ho
# 2.2  |  The black   |  A black co
# 3.8  |  A group of  |  Four peopl
# 2.6  |  A group of  |  A group of
# 0.4  |  Older man   |  A sheep in
# 4  |  The cows f  |  The brown
# 2.25  |  A small re  |  A red and
# 3.2  |  A black an  |  Black and
# 0  |  A bag of c  |  Calico cat
# 0.4  |  Two horses  |  A black an
# 3.8  |  Red double  |  A red two
# 0.8  |  The lamb i  |  A cat look
# 4.2  |  A red doub  |  A double d
# 3.6  |  A jockey r  |  A jockey r
# 2  |  The udders  |  The black
# 4.2  |  A woman po  |  a woman is
# 3.4  |  One Asian   |  Two women
# 3  |  A black tr  |  A mostly b
# 3.4  |  The brown   |  A tan dog
# 3.6  |  The black   |  The black
# 3  |  A smiling   |  Two smilin
# 2.4  |  Two airpla  |  A plane in
# 2  |  A coal tra  |  An old tra
# 4  |  A cat look  |  A grey, bl
# 0  |  World news  |  A man dres
# 4  |  Two women   |  Two smilin
# 4.2  |  A red and   |  Red and wh
# 0.8  |  A black an  |  A black an
# 2.2  |  A bicycle   |  A pink bic
# 3.8  |  Red double  |  A red doub
# 3.2  |  A bus driv  |  A green bu
# 4.4  |  An elderly  |  An older A
# 0  |  Brown and   |  A red and
# 1.4  |  People rid  |  People rid
# 2.6  |  Large silv  |  The silver
# 0.4  |  Two people  |  Two eagles
# 0  |  A scantily  |  A yellow a
# 3.2  |  Several te  |  Three tele
# 4.6  |  Sheep are   |  Sheep are
# 0  |  The small   |  The back o
# 0.6  |  Children l  |  Child milk
# 1.2  |  A black-an  |  A black an
# 3.8  |  the back o  |  The back o
# 3.2  |  Living roo  |  Living roo
# 2.6  |  Two women   |  Two women
# 5  |  A doubly d  |  A red doub
# 0  |  The black   |  The back o
# 3.2  |  A Das Air   |  A passenge
# 4  |  A cat slee  |  A black an
# 1.2  |  A close-up  |  A close-up
# 4.4  |  A kitchen   |  A kitchen
# 3.4  |  A motorcyc  |  A motorcyc
# 4.4  |  Two boys s  |  Two people
# 0.8  |  Two white   |  The birds
# 4.6  |  Large whit  |  Large crui
# 4.2  |  Two bald e  |  Two eagles
# 0  |  A backpack  |  A social g
# 3.2  |  The bird i  |  A red and
# 0  |  A group of  |  A group of
# 1.4  |  Black dome  |  A grey cat
# 3.2  |  Four child  |  Children l
# 1.8  |  A black an  |  A black an
# 1.8  |  Two men on  |  A wooden y
# 0  |  A man doin  |  A woman po
# 3.8  |  A woman eq  |  The woman
# 3.8  |  Train goin  |  A black st
# 4  |  A white pl  |  A white Sw
# 0  |  The white   |  A woman in
# 3.2  |  A group of  |  A group of
# 1.6  |  Young baby  |  A woman wi
# 3.6  |  Two cats a  |  Two baby k
# 1  |  A group of  |  A group of
# 3.6  |  A man jump  |  A man on a
# 2  |  A black an  |  A bottle o
# 3.6  |  A black an  |  Black and
# 4  |  A black an  |  A large bl
# 3.6  |  A long-hai  |  A man with
# 3.2  |  An AeroMex  |  A silver A
# 2.8  |  A red bird  |  Five birds
# 2.4  |  An older A  |  A group of
# 3.6  |  Domestic c  |  A white ca
# 1.8  |  Two cows g  |  A brown ho
# 0.2  |  A person i  |  A person w
# 3.4  |  A woman an  |  A women an
# 1.2  |  A white bi  |  A white ca
# 1.4  |  A woman at  |  Four women
# 2.6  |  A laptop c  |  A laptop a
# 2.4  |  A white ca  |  A white ca
# 0  |  A small ye  |  A small gi
# 4  |  Two women   |  Two women
# 3  |  A man with  |  A man talk
# 4  |  A close-up  |  A close-up
# 4  |  An office   |  Small offi
# 2  |  A woman le  |  A man in a
# 4  |  A man on a  |  Motorcycli
# 2.2  |  Left side   |  A close-up
# 2.2  |  Blue couch  |  A leather
# 3.4  |  A white bi  |  Old style
# 3.2  |  A bird eat  |  A yellow b
# 4  |  Black bird  |  Black bird
# 3.2  |  Dark color  |  A grey dog
# 3.8  |  A young bl  |  A young gi
# 3  |  Two brown   |  Brown hors
# 4  |  Boy lying   |  A small bo
# 2.2  |  A woman is  |  A man is l
# 3.4  |  A grey hou  |  House with
# 3.8  |  A woman wi  |  A woman le
# 0  |  Depressed   |  Older woma
# 0  |  An elderly  |  The boats
# 4.8  |  The brown   |  Brown and
# 3  |  A young wo  |  TThe girl
# 0.8  |  Black and   |  A black an
# 4.2  |  A group of  |  A group of
# 4.2  |  Two cats s  |  Two cats s
# 0  |  A man sitt  |  A women ho
# 4.2  |  A blue sco  |  A blue mop
# 4.60  |  Two gray d  |  Two grey d
# 5.00  |  Two dogs a  |  Two dogs r
# 0.00  |  The couple  |  The boy ho
# 3.20  |  German She  |  A dog jump
# 2.60  |  A group of  |  A woman ad
# 2.20  |  A dog runs  |  A wet dog
# 4.60  |  The man an  |  A man and
# 5.00  |  A man eati  |  A man sits
# 4.60  |  two young   |  two young
# 4.60  |  Two white   |  Two white
# 4.80  |  Four girls  |  Four women
# 0.60  |  Kids playi  |  Two dogs p
# 0.20  |  A man in a  |  A man is u
# 2.20  |  A black an  |  A black an
# 4.80  |  The group   |  Several hi
# 1.20  |  Two girls   |  A woman, a
# 2.20  |  A woman is  |  A man who
# 4.60  |  A young bo  |  The boy is
# 2.60  |  A black do  |  A dog is r
# 3.60  |  A man and   |  A man and
# 0.80  |  The brown   |  A brown do
# 2.40  |  Two dogs f  |  Two dogs s
# 4.80  |  The man an  |  A man and
# 5.00  |  A man prac  |  A man prac
# 0.40  |  The girl w  |  The girl i
# 3.20  |  A group of  |  A group of
# 1.80  |  A black do  |  Black dog
# 3.20  |  A small wh  |  A small wh
# 3.40  |  The white   |  The big wh
# 4.80  |  A black do  |  The black
# 4.20  |  A black an  |  A small bl
# 2.60  |  Black and   |  A black an
# 2.20  |  two dogs r  |  A dog layi
# 1.40  |  A golden d  |  A pack of
# 2.60  |  A skateboa  |  A skateboa
# 1.20  |  A girl bou  |  A girl dan
# 1.80  |  A brown an  |  the brown
# 4.00  |  a wet blac  |  A black do
# 0.40  |  Two people  |  Two men in
# 0.00  |  Two little  |  Two ladies
# 0.40  |  A woman in  |  A man and
# 3.00  |  Two people  |  Two people
# 4.00  |  A black do  |  The black
# 1.40  |  A woman in  |  A woman in
# 0.40  |  Three peop  |  A girl sta
# 2.40  |  A group of  |  A crowd of
# 2.80  |  A boy skat  |  A skateboa
# 4.60  |  A white do  |  A white do
# 4.20  |  A man and   |  A man and
# 3.20  |  a skateboa  |  A skateboa
# 1.20  |  A woman an  |  A man and
# 1.80  |  Two girls   |  two girls
# 2.60  |  Boat sails  |  A man is k
# 1.60  |  Three dogs  |  Two dogs a
# 0.00  |  A man in r  |  A man and
# 3.80  |  Two people  |  Two childr
# 4.00  |  A little b  |  A young gi
# 4.80  |  A boy ridi  |  A young bo
# 2.40  |  A black do  |  A black do
# 5.00  |  A black do  |  A black do
# 0.00  |  The man is  |  A man is l
# 3.60  |  A man and   |  A man and
# 2.40  |  Two dogs i  |  Two dogs p
# 4.20  |  Three dogs  |  Three dogs
# 0.20  |  The boy in  |  The black
# 4.20  |  Several pe  |  A group of
# 3.20  |  Two dogs f  |  Two dogs p
# 0.60  |  A group of  |  A group of
# 1.60  |  Two dogs a  |  Two dogs r
# 0.00  |  A black do  |  Kids play
# 1.40  |  A man dres  |  A woman in
# 4.80  |  A man help  |  The man he
# 4.00  |  The two do  |  The dogs p
# 3.00  |  Two dogs a  |  Two black
# 0.20  |  Two tan an  |  Lady in a
# 1.60  |  A man is r  |  Two dogs r
# 4.40  |  A seated y  |  a woman en
# 4.80  |  A black an  |  The black
# 0.40  |  A woman st  |  A man stan
# 2.40  |  Many peopl  |  A busy bea
# 3.00  |  Black and   |  A tan and
# 2.00  |  Three clow  |  Three wome
# 4.60  |  Two beige   |  two tan do
# 1.00  |  A dog and   |  A dog digs
# 5.00  |  A dog jogs  |  a dog trot
# 1.40  |  Group of l  |  a group of
# 0.00  |  A man in a  |  A woman in
# 3.00  |  A brown an  |  a dog with
# 0.60  |  A dog and   |  Two grey d
# 0.00  |  A family i  |  A naked li
# 2.60  |  a dog runs  |  A dog lays
# 1.20  |  A group of  |  A group of
# 5.00  |  There is a  |  A black do
# 3.40  |  Three dogs  |  Three dogs
# 0.80  |  A group of  |  A group of
# 0.80  |  A crowd of  |  A bunch of
# 1.00  |  A Japanese  |  A woman is
# 0.00  |  A man wear  |  A woman we
# 0.00  |  A group of  |  A group of
# 2.00  |  A man with  |  A man with
# 2.40  |  The black   |  The black
# 2.20  |  A boy is j  |  A little b
# 3.80  |  A person w  |  A person i
# 2.20  |  This dog i  |  Two dogs r
# 4.60  |  a young gi  |  A girl pos
# 2.80  |  Two women   |  Two ladies
# 2.00  |  A hockey p  |  A hockey p
# 4.20  |  Two brown   |  Two brown
# 4.50  |  Children a  |  Several ch
# 0.00  |  A dog with  |  A four whe
# 1.80  |  A black an  |  A black an
# 4.20  |  Two black   |  Two dogs p
# 4.20  |  Two boys a  |  Two boys a
# 1.40  |  A group of  |  A group of
# 3.60  |  A black pe  |  A man sitt
# 0.60  |  A man with  |  A spotted
# 5.00  |  A Golden R  |  A golden r
# 0.80  |  A man is s  |  The man is
# 0.00  |  A lady wit  |  A dog with
# 0.00  |  A skier is  |  A woman is
# 1.80  |  The dogs a  |  Two dogs p
# 0.80  |  A young bo  |  A dog is b
# 2.80  |  Two dogs a  |  A brown do
# 0.00  |  a young bo  |  Five greyh
# 0.80  |  A skateboa  |  A dog jump
# 1.80  |  Two dogs r  |  a black an
# 1.40  |  The black   |  A black an
# 1.80  |  A woman ru  |  a dog runs
# 2.40  |  A golden c  |  A black do
# 1.60  |  A white do  |  A black an
# 3.80  |  Woman in b  |  Woman in a
# 4.80  |  Two dogs a  |  Two dogs f
# 0.200000  |  Our curren  |  The car ne
# 1.000000  |  A woman su  |  A woman is
# 0.400000  |  The sky ha  |  This Lady
# 0.400000  |  The young   |  The teen r
# 4.000000  |  There are   |  The dogs a
# 3.400000  |  Some cycli  |  Two men st
# 3.000000  |  These cook  |  The women
# 1.800000  |  A man is c  |  A dog is c
# 2.200000  |  a woman wa  |  An audienc
# 3.600000  |  A girl dan  |  A girl is
# 0.400000  |  The woman   |  The man is
# 0.200000  |  The young   |  Asian chil
# 3.800000  |  A sad man   |  A man is j
# 4.200000  |  A woman is  |  A girl is
# 1.200000  |  A clown pe  |  A blond-ha
# 3.400000  |  Four girls  |  Three youn
# 2.400000  |  a group of  |  A group of
# 3.200000  |  A man play  |  A man play
# 2.200000  |  The people  |  The people
# 4.400000  |  The dogs a  |  The dogs a
# 2.600000  |  the tan do  |  A yellow d
# 0.200000  |  a girl wit  |  The girl i
# 3.200000  |  A person s  |  A woman is
# 2.200000  |  People roc  |  Two people
# 5.000000  |  A blonde w  |  The blond
# 5.000000  |  A boy is a  |  The boy is
# 2.200000  |  An old man  |  a man in a
# 0.400000  |  The carria  |  A man ridi
# 1.000000  |  A woman lo  |  A woman is
# 2.200000  |  Man sittin  |  A man is s
# 2.000000  |  A small bl  |  A young bo
# 1.200000  |  The four w  |  The women
# 4.000000  |  man on ste  |  A man sits
# 1.000000  |  There is a  |  There is a
# 4.200000  |  A woman pa  |  A person p
# 3.400000  |  Two kids a  |  The kids a
# 4.000000  |  The man is  |  The man is
# 4.800000  |  A little b  |  A boy is d
# 0.400000  |  A man has   |  A man on a
# 4.400000  |  The biker   |  A biker is
# 0.400000  |  A musician  |  Trombonist
# 0.000000  |  A pair of   |  Two smilin
# 3.000000  |  A group of  |  A group of
# 4.600000  |  A man is e  |  A man is w
# 0.400000  |  A woman wa  |  A man is s
# 1.400000  |  A man call  |  A man is o
# 3.000000  |  A young bo  |  A young bo
# 1.600000  |  A player b  |  A player c
# 2.400000  |  Men compet  |  Two women
# 0.000000  |  The puppy   |  A man in p
# 1.600000  |  A young gi  |  A boy in a
# 1.600000  |  A smiling   |  A man in a
# 0.200000  |  A person i  |  A person a
# 2.200000  |  Two men ar  |  The two wo
# 2.000000  |  The girl i  |  The man is
# 0.400000  |  Many guard  |  Two men in
# 4.800000  |  A man at a  |  A man is a
# 2.000000  |  four peopl  |  Two men wa
# 0.200000  |  A little g  |  An older c
# 3.800000  |  The child   |  The childr
# 2.200000  |  Men are fi  |  The men ar
# 2.000000  |  People are  |  People are
# 4.000000  |  A dog is c  |  A white do
# 4.600000  |  One footba  |  A football
# 1.400000  |  Three men   |  Two men ar
# 0.800000  |  A woman do  |  A woman is
# 0.600000  |  Five kids   |  People are
# 1.200000  |  Female in   |  A girl in
# 1.600000  |  Baseball p  |  A basketba
# 0.000000  |  They are p  |  Two medica
# 0.600000  |  Some smili  |  People wal
# 3.000000  |  Two fisher  |  Several me
# 2.400000  |  The woman   |  The woman
# 0.600000  |  Black and   |  a small bl
# 4.600000  |  A lady and  |  A girl and
# 0.600000  |  A boy does  |  a boy is r
# 4.800000  |  Three huma  |  Three peop
# 5.000000  |  There are   |  People are
# 0.200000  |  Two women   |  Two Asian
# 0.600000  |  A man is t  |  A little b
# 0.800000  |  Two girls   |  The two gi
# 3.600000  |  A crowd of  |  Several me
# 0.000000  |  The fruits  |  three dogs
# 4.400000  |  A doctor p  |  A doctor p
# 4.600000  |  A woman is  |  The woman
# 2.800000  |  Spectators  |  A crowd of
# 4.000000  |  The man an  |  A man and
# 1.000000  |  The boy in  |  The team i
# 5.000000  |  People are  |  People are
# 0.400000  |  Friends wa  |  a man walk
# 0.800000  |  The roller  |  Two vehicl
# 0.400000  |  There is a  |  A boy is n
# 0.000000  |  A guy and   |  Two boys a
# 1.600000  |  In Abu Dha  |  A busy cit
# 1.600000  |  A pregnant  |  a woman ha
# 3.600000  |  The religi  |  The group
# 3.000000  |  A girl in   |  A girl in
# 2.800000  |  A man is p  |  A young ma
# 0.200000  |  There was   |  The couple
# 1.000000  |  There are   |  Two racers
# 1.400000  |  A basketba  |  A tennis p
# 2.800000  |  A helicopt  |  The plane
# 3.000000  |  A man doin  |  A boy ridi
# 1.600000  |  Three guys  |  A few men
# 2.800000  |  A group wa  |  A group wa
# 4.000000  |  A woman ju  |  A woman po
# 0.800000  |  A man is o  |  A man is h
# 2.000000  |  There are   |  Three wome
# 4.400000  |  The two me  |  The two me
# 4.600000  |  The man wi  |  The man ju
# 2.400000  |  The woman   |  The woman
# 4.400000  |  A man walk  |  A man with
# 0.800000  |  The child   |  There is a
# 3.800000  |  A soccer p  |  The soccer
# 1.400000  |  Two boys i  |  Man in whi
# 2.800000  |  The player  |  The basket
# 3.000000  |  A motorcro  |  A race car
# 1.600000  |  The gate i  |  The gate i
# 1.000000  |  A dog walk  |  A boy with
# 2.600000  |  A pair of   |  Two men st
# 1.600000  |  Blond woma  |  The couple
# 0.200000  |  The raven   |  The skinny
# 3.000000  |  the man is  |  A man is k
# 3.000000  |  Two men ar  |  Two men ar
# 3.200000  |  The woman   |  The woman
# 3.00  |  You'll nee  |  If you nee
# 0.60  |  I am not a  |  At the uni
# 1.00  |  Apart from  |  Age is not
# 0.60  |  This post   |  This is ab
# 0.80  |  If you don  |  If you don
# 2.40  |  I don't th  |  You're goi
# 1.00  |  My answer   |  The proble
# 0.20  |  If you hav  |  You can ha
# 0.60  |  In general  |  For comple
# 3.60  |  It is perf  |  You can al
# 0.20  |  The academ  |  I would no
# 0.20  |  I will adv  |  You could
# 0.00  |  Edit, agai  |  I can thin
# 0.00  |  I agree wi  |  I would sa
# 1.20  |  Supporting  |  I think fo
# 0.00  |  This does   |  I am a PhD
# 0.40  |  A few poss  |  In mathema
# 0.40  |  As an comp  |  The other
# 3.00  |  Stars are   |  Stars rota
# 4.40  |  It indeed   |  In a few b
# 3.20  |  The short   |  It is high
# 3.40  |  All we kno  |  The expans
# 3.40  |  Like Chris  |  Stars are
# 3.60  |  According   |  The AAVSO
# 0.80  |  All of the  |  I will be
# 0.80  |  We are mov  |  There is n
# 1.00  |  Yes, it's   |  When you g
# 1.60  |  Let us ass  |  Globular c
# 1.00  |  Why is the  |  Speed of l
# 3.20  |  As per you  |  The main f
# 2.00  |  A method u  |  You only n
# 0.00  |  The farthe  |  Here is my
# 0.60  |  Stars form  |  It may be
# 0.00  |  A black ho  |  I think yo
# 1.40  |  Yes, but i  |  Constellat
# 2.00  |  Asteroids   |  The object
# 2.60  |  Here is a   |  Just for r
# 4.20  |  It's prett  |  On the sur
# 2.80  |  It is hard  |  Technicall
# 0.00  |  I've found  |  According
# 0.00  |  There are   |  There are
# 2.00  |  Spike trig  |  There's th
# 0.00  |  As mention  |  I like to
# 2.60  |  Q: What is  |  One human-
# 2.60  |  Intrinsic   |  According
# 0.00  |  Presumably  |  This short
# 2.60  |  When study  |  Basically,
# 0.00  |  Some ancie  |  This is in
# 1.60  |  These are   |  I'm not su
# 0.00  |  Since this  |  I'll addre
# 0.60  |  If non-hum  |  Your own t
# 1.80  |  The Hare P  |  From an ar
# 3.80  |  I wrap ste  |  Wrap well
# 1.60  |  In additio  |  I'd been u
# 3.20  |  The best w  |  Soak whole
# 2.60  |  There are   |  The differ
# 3.00  |  I've never  |  I don't bo
# 1.40  |  I just hol  |  By the wor
# 1.60  |  I've store  |  Its going
# 1.60  |  Break the   |  lay down a
# 1.00  |  I managed   |  I've only
# 1.80  |  I  believe  |  In my expe
# 1.80  |  I grill sa  |  Salmon is
# 1.40  |  The recipe  |  Starting w
# 2.60  |  They don't  |  Black pepp
# 2.00  |  This depen  |  Tomatoes w
# 1.00  |  Coagulated  |  There are
# 1.40  |  A common o  |  White fish
# 0.60  |  Good chedd  |  I have two
# 1.40  |  Copper can  |  Probably s
# 0.40  |  She obviou  |  The first
# 1.80  |  In some ca  |  There is n
# 4.00  |  I agree wi  |  I have nev
# 0.60  |  The assert  |  "I had mai
# 2.80  |  I'd sugges  |  As bikeboy
# 2.60  |  I see some  |  There are
# 2.60  |  If I under  |  Inclusion
# 0.60  |  Firstly, y  |  Semicolon
# 4.40  |  Pardon the  |  Named is p
# 2.20  |  In standar  |  I'd say th
# 1.00  |  The "more   |  As Shinto
# 0.00  |  I'm Americ  |  In situati
# 1.60  |  The room u  |  I'm Englis
# 1.80  |  I can only  |  The form i
# 3.80  |  As others   |  "Ten of si
# 3.00  |  Certainly   |  Second one
# 1.40  |  This may b  |  I'm not su
# 3.00  |  Back in th  |  The word "
# 0.40  |  Those expr  |  I suspect
# 3.60  |  In the Uni  |  Jail is a
# 3.40  |  Yes, your   |  Most style
# 2.80  |  If you und  |  Another me
# 4.20  |  There are   |  There are
# 4.20  |  You defini  |  No, don't
# 1.80  |  Yes, you s  |  Neuromuscu
# 1.00  |  I feel you  |  Sweat rate
# 2.00  |  Running do  |  Additional
# 1.00  |  I recently  |  Low reps w
# 1.60  |  Rotate thr  |  Air squats
# 2.60  |  If you're   |  There are
# 3.20  |  I've notic  |  A treadmil
# 0.40  |  Google sea  |  As @Sarge
# 0.00  |  Since you'  |  In general
# 0.00  |  First of a  |  You can mi
# 2.20  |  Properly e  |  I've seen
# 1.50  |  I think it  |  I haven't
# 0.60  |  It is not   |  Adding soa
# 4.00  |  Yes, you c  |  Absolutely
# 1.80  |  There are   |  I brought
# 0.60  |  Pick them   |  I live in
# 1.60  |  Thistle is  |  I've got t
# 2.40  |  Support is  |  Some suppo
# 1.00  |  To paraphr  |  First, let
# 2.00  |  Just about  |  We have qu
# 1.60  |  Chances ar  |  The longer
# 0.20  |  So you kno  |  Since you'
# 0.20  |  In the pas  |  Additional
# 2.00  |  There is a  |  It is mean
# 0.00  |  I found it  |  I reccomen
# 3.20  |  Simple ans  |  It appears
# 1.00  |  Dirt can m  |  Use coco p
# 2.00  |  If you can  |  The NPK nu
# 2.40  |  The point   |  Your pile
# 0.00  |  I bought a  |  Well I wou
# 1.60  |  Aloes, lik  |  Some of th
# 3.80  |  This looks  |  I concur w
# 1.20  |  Some villa  |  Many towns
# 2.00  |  The USA is  |  The United
# 1.00  |  Nearly all  |  The USSR g
# 2.00  |  While Quee  |  There is a
# 0.60  |  To no exte  |  They had a
# 0.00  |  "What I am  |  The follow
# 0.00  |  In Hinduis  |  This relat
# 3.40  |  I guess th  |  That is in
# 2.60  |  These are   |  I guess th
# 0.40  |  Looks like  |  There was
# 2.80  |  Yes, I can  |  It is true
# 2.00  |  By the tim  |  The Han Dy
# 1.60  |  There were  |  As per you
# 1.40  |  "The grass  |  As noted o
# 1.20  |  http://en.  |  I am not e
# 2.20  |  Dominus, p  |  A greek-sp
# 0.60  |  The bulk o  |  I believe
# 2.60  |  Yes, this   |  Indefinite
# 3.00  |  Preserving  |  In fact, y
# 2.20  |  In some no  |  Modern Eng
# 1.80  |  The diffic  |  It depends
# 0.60  |  In English  |  In traditi
# 0.00  |  A caveat:   |  I agree wi
# 1.60  |  The reason  |  Although I
# 0.80  |  Palatalisa  |  Sinhala, o
# 0.20  |  All the sa  |  One idea t
# 1.00  |  Newspeak,   |  Every lang
# 2.80  |  In Russian  |  As in Russ
# 0.60  |  As you can  |  This is an
# 2.80  |  Zipf’s law  |  As with al
# 1.60  |  A part of   |  "Phoneme"
# 1.40  |  If you are  |  This is wh
# 1.40  |  From what   |  According
# 3.00  |  A tent may  |  No, a tent
# 3.20  |  A few poin  |  In general
# 2.80  |  Nylon drie  |  Nylon, amo
# 3.40  |  GPS (wikip  |  GPS system
# 2.00  |  Different   |  American b
# 2.80  |  So it's im  |  Skiing is
# 0.00  |  In a gym,   |  Alright, t
# 0.20  |  I visit AZ  |  Apart from
# 0.80  |  A wonderfu  |  If you can
# 0.00  |  An embolis  |  Here is an
# 4.20  |  It would b  |  I'm no her
# 0.20  |  As I wrote  |  Unlike oth
# 3.20  |  Once you o  |  Boiling el
# 0.00  |  Different   |  You can ge
# 0.60  |  If you wea  |  The above
# 0.00  |  Oh friend,  |  Yes, it is
# 4.80  |  My opinion  |  My opinion
# 3.80  |  You are sa  |  I would sa
# 1.80  |  He is taki  |  You can tr
# 0.40  |  I would re  |  Would you
# 2.60  |  Yes, twins  |  Here's wha
# 1.60  |  Whatever y  |  We always
# 1.40  |  A rule of   |  Any breed
# 2.00  |  I know of   |  Baby talk,
# 1.80  |  A possibil  |  Many child
# 1.20  |  The point   |  I've found
# 0.80  |  You should  |  It is alwa
# 2.20  |  You will b  |  The topics
# 3.20  |  Although c  |  As was men
# 1.40  |  Both of ou  |  Yours look
# 1.40  |  I have nev  |  We used a
# 0.00  |  I'm facing  |  An alterna
# 1.60  |  My son did  |  Here are s
# 0.80  |  Show her h  |  You can pu
# 2.80  |  Our daught  |  My wife an
# 1.80  |  Playing do  |  I have bee
# 0.67  |  Most docto  |  Eating off
# 2.60  |  Most of th  |  In my expe
# 0.40  |  Here is my  |  I understa
# 2.40  |  It is poss  |  We tried p
# 2.80  |  Turtles lo  |  First, the
# 2.00  |  Given that  |  To reduce
# 3.00  |  My experie  |  Breed Zebr
# 2.60  |  I have see  |  I think Ke
# 1.80  |  Cats (and   |  They don't
# 3.80  |  It does so  |  Something
# 3.00  |  I have not  |  Cats may o
# 1.40  |  How could   |  In my 200
# 1.60  |  First, dou  |  First, you
# 0.00  |  The approp  |  The info y
# 0.60  |  My guess i  |  Some resea
# 0.00  |  Cover the   |  I started
# 3.40  |  Try switch  |  As mention
# 3.60  |  You should  |  As covered
# 2.20  |  The main c  |  Allergies
# 3.00  |  There are   |  John Cavan
# 1.80  |  Stocking i  |  You'll alw
# 2.40  |  The best a  |  A trick I
# 2.60  |  I don't ha  |  Bettas are
# 1.40  |  We always   |  We had a c
# 1.60  |  The bigges  |  Cats don't
# 1.60  |  Breed Zebr  |  Supposedly
# 1.40  |  Clean the   |  Others hav
# 2.80  |  Aristotle   |  Why did Ar
# 3.80  |  I don't th  |  I am not c
# 3.40  |  Well for o  |  The differ
# 0.00  |  People who  |  My motivat
# 2.00  |  The differ  |  sufficient
# 0.00  |  I have no   |  It's a tau
# 3.80  |  It's true   |  Accessibil
# 0.20  |  I once met  |  Although I
# 0.60  |  If a state  |  Should arr
# 1.80  |  The Questi  |  The least
# 1.80  |  I think th  |  Wittgenste
# 1.20  |  Forget for  |  As others
# 0.00  |  The questi  |  wikipedia,
# 1.00  |  Not all ne  |  I don't th
# 0.40  |  As I under  |  Our intera
# 0.80  |  I can imag  |  It is the
# 3.00  |  When I nee  |  An alterna
# 3.80  |  Fast Pictu  |  Fast Pictu
# 3.20  |  There are   |  There are
# 2.60  |  Apart from  |  The wider
# 3.00  |  When print  |  It refers
# 2.60  |  You need t  |  In my expe
# 1.80  |  I have a f  |  If your in
# 2.60  |  I have fou  |  There are
# 0.80  |  I've used   |  In Linux I
# 1.60  |  A class 6   |  Some cards
# 0.60  |  Here are m  |  It's a 1:1
# 2.60  |  Same here,  |  I have the
# 1.20  |  I use Elin  |  Or just go
# 0.00  |  The short   |  Speaking f
# 2.40  |  The termin  |  Lossless /
# 0.40  |  For what i  |  Regular di
# 0.60  |  Large-form  |  If I had t
# 1.00  |  Anil, ther  |  If you wan
# 2.60  |  Freezing m  |  In additio
# 4.00  |  Federal DO  |  DOMA as a
# 3.60  |  Public emp  |  The legal
# 2.60  |  The U.S. a  |  There are
# 1.60  |  Leaving as  |  Healthcare
# 4.00  |  The presid  |  The functi
# 3.00  |  In a "firs  |  While the
# 0.60  |  The part o  |  Side note
# 0.00  |  Let me sha  |  I am sure
# 0.40  |  Most peopl  |  To start,
# 0.40  |  I'm not ye  |  There are
# 2.00  |  No, nothin  |  There is a
# 0.60  |  Russian Fe  |  The last r
# 0.00  |  This quest  |  Minimum wa
# 3.20  |  According   |  As with th
# 2.80  |  Because th  |  They do no
# 2.60  |  Absolute m  |  In countri
# 2.80  |  Professor   |  Minimum wa
# 0.20  |  The Univer  |  This is st
# 3.20  |  Before you  |  As Eugene
# 0.60  |  Eclipse Be  |  To train y
# 3.60  |  As others   |  I've been
# 0.00  |  The import  |  I have bee
# 0.00  |  I think yo  |  One genera
# 0.00  |  A quick re  |  The issue
# 0.00  |  Here's a t  |  I agree wi
# 2.20  |  I have a s  |  As mention
# 0.00  |  Even thoug  |  I don't kn
# 0.40  |  Your brain  |  I'm writin
# 0.00  |  To stick w  |  There is a
# 2.60  |  I think 90  |  Definitely
# 0.80  |  The user n  |  Instead of
# 0.40  |  I like the  |  Buy a 3 pa
# 3.00  |  I'd start   |  I'm consid
# 2.20  |  The best w  |  What works
# 0.60  |  I disagree  |  Research d
# 3.40  |  Currently   |  My GTD sys
# 2.20  |  Feel the f  |  13 Tips To
# 1.80  |  I've recen  |  http://www
# 0.80  |  I would sa  |  There's al
# 0.00  |  Some studi  |  There's an
# 1.60  |  Experience  |  I think a
# 2.80  |  There is a  |  The capita
# 1.67  |  I disagree  |  The most e
# 1.80  |  I'd be mor  |  It is not
# 2.80  |  On the one  |  Time Turne
# 0.00  |  I was invi  |  It's obvio
# 0.60  |  First of a  |  I always t
# 1.80  |  I started   |  Without de
# 0.40  |  I voted fo  |  Allen Stee
# 0.20  |  It was bef  |  The exact
# 0.00  |  We have tw  |  Our intrep
# 1.40  |  Dick was a  |  Most of Ph
# 0.00  |  First, we   |  "Fins" on
# 0.60  |  According   |  In real-wo
# 0.80  |  I don't th  |  The short
# 0.20  |  Here is th  |  Wikipedia'
# 2.20  |  Sign langu  |  It is safe
# 1.80  |  Remember,   |  Well, it r
# 0.20  |  This idea   |  The scienc
# 4.00  |  Is it poss  |  Yes, it's
# 4.20  |  Yes a team  |  There's no
# 4.40  |  It is simp  |  Bowling st
# 3.00  |  Yes, absol  |  Yes, the r
# 2.60  |  We only us  |  Fartlek is
# 0.60  |  If the num  |  This is th
# 3.20  |  Women firs  |  In 1900, t
# 2.60  |  It is hard  |  Drafting h
# 1.20  |  To play go  |  Having fai
# 3.00  |  Yes, dew (  |  Another di
# 0.00  |  Reading yo  |  I'd say yo
# 2.60  |  There is N  |  There is a
# 1.20  |  Basically,  |  It is fair
# 2.80  |  At the hig  |  From perso
# 0.20  |  I can thin  |  There have
# 1.80  |  The moveme  |  Both of th
# 0.00  |  Actually,   |  That is al
# 0.00  |  Red ball u  |  I am too a
# 3.00  |  No, there   |  As per the
# 0.00  |  I can't th  |  The Laws o
# 2.40  |  As per FIF  |  Although h
# 0.40  |  Glad to he  |  A general
# 2.60  |  I prefer t  |  I would de
# 0.00  |  It was ran  |  This was t
# 3.60  |  For the mo  |  Generally
# 1.80  |  There is o  |  There are
# 1.60  |  I'd sugges  |  I am not s
# 2.00  |  As I remem  |  This page
# 2.00  |  My experie  |  When using
# 0.00  |  I had a si  |  I'm actual
# 2.60  |  A technica  |  Usually it
# 0.40  |  Kyoto, at   |  Coin locke
# 0.00  |  There's a   |  It's prett
# 0.20  |  I visited   |  Cusco: Hig
# 1.80  |  Generally,  |  There are
# 1.60  |  The most o  |  Look at th
# 1.00  |  The answer  |  As someone
# 0.60  |  There are   |  As others
# 1.00  |  Would goin  |  Ozbus offe
# 2.80  |  English wo  |  I traveled
# 2.60  |  I think th  |  I think it
# 3.40  |  There is n  |  The minima
# 1.60  |  I've start  |  I've tried
# 4.00  |  Yes, this   |  I believe
# 1.80  |  For fictio  |  To answer
# 0.20  |  David Webe  |  One thing
# 0.00  |  You have t  |  Whenever I
# 1.40  |  Your worry  |  I don't be
# 0.00  |  No, you do  |  I have don
# 1.20  |  One thing   |  I noticed
# 3.60  |  We just ad  |  guillemets
# 3.00  |  The villai  |  A villain
# 1.20  |  You can wr  |  Sequence a
# 1.80  |  Yes, dull   |  I agree wi
# 0.80  |  The answer  |  At first,
# 1.20  |  Webster's   |  http://www
# 0.00  |  Keep in mi  |  I think St
# 3.20  |  In these d  |  I agree wi
# 0.20  |  I have bee  |  Am I allow
# 0.800  |  The techno  |  The broad
# 3.600  |  "It's a hu  |  "It's a hu
# 5.000  |  He later l  |  He later f
# 1.400  |  RT Jones a  |  He has a v
# 2.600  |  A key ques  |  France, wh
# 2.000  |  Mel Gibson  |  Mel Gibson
# 3.750  |  Executive   |  Executive
# 4.000  |  The decade  |  More than
# 3.750  |  Tom Kasmer  |  The 14-yea
# 3.200  |  The budget  |  Budget neg
# 4.000  |  Also at in  |  Also at in
# 2.400  |  Shares of   |  In morning
# 4.400  |  "I feel th  |  The people
# 4.200  |  "Generally  |  Generally
# 3.200  |  The retail  |  The decisi
# 3.000  |  Lord Falco  |  "It's a ne
# 0.800  |  The techno  |  The broad
# 3.200  |  Business W  |  BusinessWe
# 3.800  |  "I started  |  Gulping fo
# 3.000  |  It was the  |  For the th
# 2.400  |  GM, the wo  |  They cover
# 5.000  |  The compan  |  The compan
# 3.800  |  North Amer  |  North Amer
# 3.200  |  The Standa  |  The Standa
# 3.800  |  "I know of  |  "I know of
# 3.800  |  "She was c  |  "She was c
# 3.750  |  "Frank Qua  |  Quattrone
# 3.200  |  The dollar  |  The dollar
# 3.400  |  Germans ac  |  Germans re
# 4.600  |  Also in Mo  |  Near a mos
# 3.333  |  Mr. Bush h  |  In Texas,
# 3.500  |  This integ  |  IBM said t
# 1.750  |  Freeman's   |  Freeman sa
# 3.000  |  Protesters  |  The protes
# 4.400  |  Another mi  |  A Spanish
# 3.800  |  Singapore   |  Although a
# 3.000  |  After 9/11  |  Connolly s
# 4.500  |  Calvin Hol  |  The lawyer
# 2.200  |  PG&E Corp.  |  PG&E's sha
# 4.000  |  "This deci  |  The decisi
# 4.600  |  Paul Themb  |  MDC spokes
# 3.500  |  He claims   |  "This prop
# 3.000  |  YES filed   |  The suit w
# 4.000  |  He will be  |  Dynes will
# 4.333  |  His daught  |  Axelrod di
# 3.250  |  Deaths in   |  Fatalities
# 3.250  |  The pound   |  The Britis
# 1.750  |  The Record  |  That is, i
# 0.800  |  The broade  |  The techno
# 4.400  |  Earlier Th  |  Thursday m
# 3.000  |  Both paper  |  The study
# 3.000  |  The WHO ex  |  Hebei has
# 3.250  |  "I do not   |  "Yes, I do
# 4.400  |  They are b  |  Both men a
# 5.000  |  The report  |  The report
# 5.000  |  Who will s  |  There is n
# 3.200  |  Under the   |  The U.S. H
# 2.200  |  The Securi  |  That feder
# 3.250  |  Lee Janzen  |  Lee Janzen
# 3.750  |  Tenet has   |  In Novembe
# 3.200  |  Dotson was  |  Dotson, 21
# 4.400  |  The bank a  |  The offer
# 2.600  |  "They've b  |  The quarte
# 3.500  |  The world'  |  The world'
# 3.750  |  But price   |  McArthur t
# 3.500  |  Putin hail  |  Before the
# 4.250  |  Appellate   |  Lower cour
# 2.400  |  He was arr  |  He was arr
# 3.250  |  The effort  |  July 10 -
# 3.800  |  The shares  |  The sale r
# 3.400  |  Sirius car  |  Sirius rec
# 3.500  |  Mahmud con  |  Mahmud con
# 2.400  |  According   |  According
# 3.800  |  Actor Noah  |  Noah Wyle,
# 3.800  |  The WHO sa  |  The WHO ha
# 4.000  |  U.S. troop  |  U.S. soldi
# 3.400  |  It got up   |  "It got up
# 3.250  |  A former c  |  Mr. McCall
# 4.600  |  FBI agents  |  A former p
# 3.714  |  Yeager sai  |  Yeager sai
# 3.333  |  The 30-yea  |  The 30-yea
# 3.400  |  "If that a  |  And if tha
# 2.800  |  "It's a ma  |  The Maine
# 3.000  |  The Embrae  |  The Bombar
# 3.000  |  "I can say  |  "I am bein
# 3.750  |  Investigat  |  Investigat
# 4.400  |  Revenue ro  |  Revenue wa
# 1.000  |  The broad   |  The techno
# 2.800  |  Neither Io  |  Iowa State
# 3.250  |  The male e  |  The 21-yea
# 1.750  |  Agnew said  |  Still, Pin
# 1.750  |  Marc Garbe  |  Whitley's
# 5.000  |  BioRelianc  |  Shares of
# 3.600  |  Just five   |  Just five
# 3.000  |  Artists ar  |  The artist
# 2.800  |  At his req  |  District S
# 3.600  |  A federal   |  A federal
# 3.000  |  The time w  |  The seizur
# 1.000  |  The techno  |  The broade
# 5.000  |  EU ministe  |  Gerry Kiel
# 3.500  |  "Now, the   |  "The other
# 4.500  |  In his new  |  Dynes will
# 4.800  |  But in the  |  But Vincen
# 3.500  |  Justices s  |  In a 6-3 r
# 3.692  |  The vetera  |  Razali Ism
# 4.000  |  At first b  |  At first b
# 3.500  |  Ukrainian   |  The disput
# 4.750  |  Chechen of  |  Officials
# 3.200  |  About 25 g  |  According
# 2.600  |  The panel   |  It called
# 3.000  |  The compan  |  The servic
# 3.250  |  Gold's ris  |  Gold's bou
# 2.200  |  Shares of   |  Shares of
# 3.500  |  It will co  |  It will co
# 4.750  |  Teams of i  |  Teams of i
# 3.200  |  The identi  |  The rovers
# 3.250  |  Representa  |  Puretunes
# 3.750  |  I've still  |  "I'm still
# 3.000  |  Two astron  |  Astronomer
# 2.600  |  "What they  |  The church
# 3.250  |  The woman   |  The woman
# 3.400  |  The Americ  |  The Americ
# 1.333  |  Amgen shar  |  Shares of
# 5.000  |  The last t  |  In 1995, t
# 4.000  |  Higher cou  |  The federa
# 3.600  |  In two wee  |  Frankel sa
# 0.800  |  The techno  |  The broade
# 3.500  |  He allowed  |  Zambrano p
# 3.000  |  Still, he   |  "I'm absol
# 1.667  |  Nationally  |  There were
# 3.750  |  On Thursda  |  On Thursda
# 2.250  |  Mr. Heatle  |  Heatley un
# 4.200  |  Former com  |  Last week,
# 3.600  |  U.S. Distr  |  FirstEnerg
# 3.400  |  Mr Pollard  |  Nick Polla
# 3.000  |  "They were  |  "The concr
# 3.250  |  "IT is the  |  "IT is the
# 3.600  |  The new sy  |  The system
# 3.000  |  The router  |  Netgear pr
# 1.750  |  On Monday,  |  Last Thurs
# 3.250  |  The first   |  Emile Laro
# 4.400  |  "I'm not g  |  "I'm not g
# 2.800  |  Dixon was   |  Scott Dixo
# 2.750  |  By Sunday   |  Major fire
# 3.000  |  U.S. force  |  U.S. force
# 3.600  |  They came   |  BA said th
# 3.000  |  The author  |  Spitz is e
# 2.000  |  The two-ye  |  The benchm
# 3.000  |  As part of  |  Peregrine
# 4.400  |  Part of th  |  A key port
# 2.400  |  Shares in   |  Shares in
# 4.400  |  The compan  |  Chiron and
# 4.400  |  Investigat  |  Investigat
# 2.600  |  Joining St  |  The Intern
# 3.000  |  The Winsto  |  Six new Kr
# 4.500  |  The report  |  There will
# 3.000  |  Families s  |  Families s
# 1.750  |  For the en  |  "The avera
# 2.000  |  Orange sha  |  France Tel
# 2.400  |  A search f  |  Authoritie
# 4.800  |  Beleaguere  |  Two federa
# 4.000  |  He claimed  |  In his let
# 4.000  |  Police the  |  While wait
# 4.400  |  At 12 mont  |  At 12 mont
# 4.200  |  "It just s  |  "It just s
# 3.600  |  "City-grow  |  "I know th
# 2.500  |  The Standa  |  The broad
# 1.500  |  The Dow Jo  |  The Dow Jo
# 5.000  |  "We hope a  |  China's fo
# 3.750  |  School off  |  Van-Vliet,
# 1.750  |  Board Chan  |  Mr. Mills
# 4.400  |  Its former  |  Chief Exec
# 3.000  |  Police bel  |  Police bel
# 3.800  |  According   |  The Telegr
# 3.250  |  Bulger's b  |  Bulger's b
# 2.750  |  Florida's   |  On Tuesday
# 3.400  |  "The Europ  |  Tito Barbi
# 3.200  |  "It was a   |  "We're in
# 2.000  |  From Broad  |  Playwright
# 3.000  |  Nine secon  |  Nine secon
# 3.250  |  The plane   |  US Airways
# 5.000  |  Gainer sai  |  The securi
# 3.333  |  He also sa  |  The academ
# 3.600  |  Gartner's   |  Total ship
# 3.800  |  Roy Moore,  |  Moore, the
# 3.000  |  The blue-c  |  The blue-c
# 4.250  |  An arrest   |  According
# 3.500  |  FRIENDS of  |  Hollywood
# 3.200  |  But JT was  |  "However,
# 2.400  |  Shares of   |  Halliburto
# 4.000  |  Tail waggi  |  On Monday,
# 4.667  |  At midnigh  |  With 97 pe
# 3.333  |  Graham is   |  Later Tues
# 3.000  |  "These cha  |  Still, cha
# 3.250  |  Barbini sa  |  Barbini sa
# 4.000  |  The blaze   |  The fire s
# 3.500  |  Sources sa  |  Agents con
# 2.000  |  The helico  |  The helico
# 3.600  |  "I am advi  |  "I am advi
# 3.400  |  The new re  |  It will ap
# 3.500  |  Two convic  |  A convicte
# 2.400  |  John Hicke  |  Hickenloop
# 3.500  |  Young has   |  Under NASD
# 2.800  |  Stocks dip  |  Wall Stree
# 4.800  |  From the s  |  But the Un
# 3.000  |  Selenski d  |  Selenski u
# 3.400  |  Common sid  |  The most c
# 3.250  |  Announcing  |  Together,
# 4.750  |  Supermarke  |  Supermarke
# 3.600  |  INTEL TODA  |  Intel on W
# 4.200  |  The 6th U.  |  An Ohio la
# 2.000  |  The Nasdaq  |  The techno
# 3.800  |  "We're goi  |  "There's v
# 1.600  |  The compan  |  The compan
# 3.250  |  Shares of   |  Shares of
# 5.000  |  The upcomi  |  They say s
# 3.417  |  That took   |  That saw t
# 2.750  |  The bank's  |  Shares of
# 4.111  |  In the lat  |  Early Mond
# 3.600  |  Consumer g  |  Consumer g
# 3.600  |  Every Thur  |  A grains m
# 4.333  |  Colin Powe  |  Secretary
# 3.200  |  Stout prev  |  Stout come
# 2.250  |  Scrimshaw,  |  Best Minis
# 4.500  |  Former Sou  |  South Afri
# 2.750  |  In Septemb  |  Four month
# 4.000  |  Consumers   |  To watch p
# 3.400  |  On Friday,  |  Yesterday,
# 2.200  |  A Stage 1   |  The federa
# 3.250  |  While wait  |  The bomb e
# 3.667  |  "It seems   |  "Leaving a
# 4.750  |  The Americ  |  The U.S. w
# 3.500  |  Its maker,  |  MedImmune
# 3.000  |  Kaichen ap  |  She appear
# 3.250  |  An increme  |  The increm
# 3.600  |  Bush turne  |  Mr. Bush d
# 3.800  |  The govern  |  The govern
# 1.000  |  The broade  |  The techno
# 3.333  |  Crews work  |  Crews work
# 4.250  |  Buoyed by   |  Buoyed by
# 1.750  |  Net revenu  |  That is up
# 2.750  |  These men   |  "The petit
# 3.250  |  The mock e  |  The mock e
# 2.500  |  The commis  |  Patton als
# 3.091  |  Aiken's st  |  The findin
# 4.400  |  A Merrill   |  "We are ve
# 4.800  |  Trans fats  |  Trans fats
# 5.000  |  But skepti  |  But skepti
# 3.000  |  Crohn's di  |  Symptoms i
# 3.200  |  Authoritie  |  Powell is
# 4.4  |  Netanyahu   |  Israel's N
# 1.8  |  Annan, UN   |  Russia, Ch
# 4  |  Green Lant  |  Green Lant
# 1  |  Military p  |  Military p
# 0.6  |  Saudi gas   |  Nigeria ch
# 4.6  |  Coty launc  |  Coty bids
# 1.8  |  Greece vot  |  Greece loo
# 1.2  |  Iran warns  |  Iranians “
# 4.6  |  Mohamed Mo  |  Mohamed Mo
# 1.4  |  1 person k  |  Nine kille
# 3.2  |  IAF strike  |  IAF strike
# 2.8  |  US senator  |  US decries
# 0.8  |  Syrian env  |  Syria depl
# 3.8  |  Dali paint  |  Salvador D
# 3.8  |  Annan urge  |  Annan urge
# 4.2  |  Colorado s  |  Lawyers: C
# 1.6  |  Suicide bo  |  Suicide bo
# 3.8  |  PM in Tehr  |  Manmohan i
# 1.4  |  Senators c  |  Messi scor
# 3.6  |  South Afri  |  South Afri
# 1.8  |  Civilians   |  Taliban la
# 3.8  |  Russia, Ch  |  Russia, Ch
# 0.2  |  Syrians tr  |  Israel bra
# 1.6  |  Israeli Le  |  Israeli ar
# 0.4  |  Government  |  Finance mi
# 2.33333333  |  Egyptian p  |  Egypt's Pr
# 0.4  |  Japan fall  |  Japan than
# 3.6  |  Syrian tro  |  Activists:
# 3.4  |  Suspicious  |  Police tre
# 2.6  |  At least 1  |  At least 1
# 2.2  |  US drone s  |  US drone s
# 2.6  |  Obama endo  |  Obama's de
# 4.8  |  Jordan Ope  |  Jordan Ope
# 4.8  |  Eurozone b  |  Eurozone a
# 4.8  |  Two blasts  |  Two blasts
# 2.6  |  Barack Oba  |  Obama back
# 1.6  |  Police dis  |  Police dis
# 2.2  |  2 pro-Pale  |  Dozens of
# 1  |  Spanish jo  |  US jobless
# 1.2  |  Israeli PM  |  Israel bla
# 3.4  |  Music Indu  |  Music indu
# 0.6  |  Five dead   |  Over 120 d
# 3.2  |  At CPAC, M  |  CPAC 2012:
# 3.2  |  Glorious t  |  Britain sa
# 1.8  |  Toulouse s  |  Toulouse s
# 1.2  |  Wigan 3-2   |  Arsenal 0-
# 1.6  |  UK spends   |  US spends
# 4.8  |  Lance Arms  |  Lance Arms
# 3.6  |  Prince Phi  |  Britain's
# 3.8  |  'Desperate  |  'Housewive
# 3  |  Gaza rocke  |  Rocket fir
# 3.6  |  Egypt's Co  |  Egypt prep
# 4.4  |  EU Set for  |  EU plans m
# 2  |  Assad meet  |  Assad make
# 2.4  |  Manchester  |  Manchester
# 3.2  |  Soggy sols  |  Summer sol
# 3.4  |  ICC lawyer  |  ICC lawyer
# 2.8  |  Freight tr  |  Freight tr
# 3.2  |  China yuan  |  China's yu
# 1.8  |  Breivik co  |  Breivik: J
# 2.8  |  Romney roc  |  Romney tap
# 3.4  |  Eurozone a  |  Eurozone t
# 4.6  |  South Kore  |  S. Korean
# 3.8  |  Russia, Ch  |  Russia, Ch
# 1.6  |  Juror: San  |  Jerry Sand
# 0.8  |  Romney lea  |  Romney: I
# 1  |  9/11 defen  |  Sept. 11 d
# 2.6  |  Egyptians   |  Egyptians
# 4.2  |  Sly Stallo  |  Sylvester
# 4.4  |  Clinton: U  |  Clinton: U
# 2.2  |  Romney, Ob  |  Obama and
# 2.6  |  Roadside b  |  Roadside b
# 2.8  |  Remarks by  |  The Presid
# 4  |  Malawi con  |  Malawi con
# 3.2  |  Venezuela'  |  Venezuelan
# 0  |  Residents   |  Best’s gre
# 1.8  |  Syria in c  |  Syrian cea
# 0  |  Spurs get   |  Abduct Isr
# 2.6  |  China's CP  |  China's in
# 2.75  |  Gaza milit  |  Gazans fir
# 3.2  |  Iraq Relea  |  Iraq Said
# 1.8  |  Suicide bo  |  Suicide bo
# 4.2  |  7 detained  |  China deta
# 4.2  |  China Yuan  |  China yuan
# 2.6  |  Texas resi  |  Residents
# 4.2  |  Shinzo Abe  |  Shinzo Abe
# 2  |  2 dead in   |  Bangladesh
# 5  |  De Blasio   |  Bill De Bl
# 0.8  |  China to r  |  China and
# 3.8  |  'Around 10  |  Hundreds d
# 1.6  |  Nelson Man  |  Nelson Man
# 3.4  |  Cardinals   |  Cardinals
# 0.6  |  AU leaders  |  Egypt Yout
# 1.4  |  Today in H  |  Today in H
# 3.8  |  UK alert o  |  West raise
# 1.2  |  Israelis,   |  Israeli la
# 3  |  Moderate e  |  Moderate e
# 2.2  |  32 die in   |  1 Killed i
# 1  |  Thai polic  |  Brazil lea
# 2.2  |  Calif man   |  Calif. man
# 1.8  |  Motorists   |  Cars trapp
# 0  |  Chinese sh  |  Chinese st
# 4.2  |  Red grapes  |  Red grapes
# 0.4  |  2 police k  |  At least 2
# 2.6  |  The Note's  |  The Note's
# 0.6  |  Lebanon bu  |  Tunisia pr
# 3.8  |  Indian pol  |  Mumbai pol
# 0  |  Security t  |  Security a
# 5  |  Google inv  |  Google inv
# 1  |  China stri  |  Insurance
# 3.2  |  Demolition  |  Demolition
# 2.8  |  US confirm  |  US capture
# 4.6  |  London Mar  |  London Mar
# 3.4  |  Messi nets  |  Football:
# 1.2  |  Ukrainian   |  Ukrainian
# 4  |  Two NATO s  |  NATO soldi
# 1.8  |  The Note's  |  The Note's
# 4  |  Deaths con  |  Scottish p
# 2.4  |  North Kore  |  North Kore
# 1.8  |  Stocks clo  |  Stocks clo
# 3.8  |  Afghan leg  |  Afghan pre
# 1.4  |  Almagor bl  |  Yacimovich
# 2.6  |  Hospital:   |  Dozens rep
# 1.4  |  Clashes er  |  Coptic pri
# 1.6  |  Queen pays  |  US preside
# 4.8  |  Iran says   |  Iran says
# 0.8  |  No radiati  |  US Congres
# 3.4  |  Bangladesh  |  Bangladesh
# 3.2  |  Iran leade  |  Iran Presi
# 2.2  |  Singapore   |  Singapore
# 1.2  |  2 Pussy Ri  |  Freed Puss
# 3  |  Israel lau  |  Israel lau
# 2.6  |  Floods lea  |  Heavy rain
# 0.4  |  Iran Moder  |  Iran threa
# 4.6  |  New World   |  One World
# 4  |  Fashion de  |  Designer,
# 2.8  |  New Japan   |  Japan, US
# 3.8  |  Websites b  |  Websites f
# 0  |  Turkish po  |  British po
# 3.4  |  Guatemala   |  Held in Gu
# 4.6  |  Biden call  |  Biden call
# 0.8  |  4 dead aft  |  8 dead aft
# 3.8  |  Cannes thi  |  Robber ste
# 2.2  |  Nelson Man  |  ‘Nelson Ma
# 3.2  |  US Militar  |  US militar
# 5  |  Kenya Supr  |  Kenya SC u
# 1.6  |  Death toll  |  Thousands
# 2.2  |  Nicaragua,  |  Bolivia's
# 0.8  |  5 killed,   |  3 killed,
# 3.6  |  At least 3  |  Dozens of
# 2.5  |  Chinese sh  |  China stoc
# 3  |  Miss New Y  |  Miss New Y
# 2.2  |  Four kille  |  Egypt viol
# 0  |  China deta  |  Napthine t
# 0.2  |  US Senator  |  SFG meetin
# 3.20  |  One dead i  |  Six confir
# 5.00  |  Matt Smith  |  Matt Smith
# 2.20  |  Rescuers s  |  Select ima
# 4.40  |  19 hurt in  |  Police: 19
# 3.80  |  Another mi  |  Another mi
# 1.20  |  Scores Kil  |  Turkey's P
# 4.60  |  Michelle O  |  Michelle O
# 3.80  |  Rosberg em  |  FORMULA 1:
# 1.40  |  Brooks ple  |  Dave Lee T
# 3.80  |  Protesters  |  Protesters
# 0.00  |  France cle  |  Manila to
# 1.60  |  Egypt arre  |  Egypt brac
# 5.00  |  Israel exp  |  Israel wid
# 0.40  |  Syrian for  |  Hunting fo
# 2.40  |  Libya asks  |  Kerry Call
# 3.20  |  Tornadoes   |  Tornadoes
# 3.80  |  Margaret T  |  Margaret T
# 2.60  |  One dead i  |  Six killed
# 1.00  |  6.4-magnit  |  6.9-magnit
# 4.00  |  Police hel  |  Helicopter
# 2.00  |  Quotes fro  |  Obama shak
# 2.20  |  Gunmen 'ki  |  Gunmen kil
# 4.60  |  Major fire  |  Fire break
# 4.40  |  China-EU 2  |  Full text:
# 1.80  |  Chinese sh  |  Chinese sh
# 0.00  |  Global pro  |  Iran diplo
# 0.00  |  Greek poli  |  Israel pre
# 2.00  |  UN Chemica  |  US Says Ch
# 3.40  |  Syria agre  |  Syria FM:
# 0.20  |  Fatah endo  |  Pakistan D
# 2.40  |  Attack kil  |  NATO: 3 tr
# 0.00  |  Food poiso  |  Baghdad ca
# 0.40  |  Zoo worker  |  Indian-ori
# 1.80  |  Six killed  |  12 killed
# 0.80  |  17 govt em  |  At least 7
# 0.40  |  At least 1  |  At least 1
# 2.20  |  Israel 'bo  |  Fierce cla
# 1.80  |  US, Russia  |  US and Rus
# 4.60  |  Australia   |  Australia
# 2.20  |  Syria oppo  |  Syria divi
# 1.00  |  Internatio  |  Arrested B
# 1.00  |  Obama sign  |  Obama urge
# 4.20  |  Fire in Ru  |  38 feared
# 0.40  |  DPRK leade  |  North Kore
# 0.20  |  Chinese, R  |  Chinese pr
# 0.00  |  Poll: Cory  |  Nigella La
# 0.00  |  Blast on I  |  State: No
# 0.00  |  Iran threa  |  Man admits
# 0.60  |  Manchester  |  Manchester
# 0.60  |  Foreign co  |  More carri
# 4.00  |  U.S. fast-  |  Fast-food
# 0.00  |  All eyes o  |  Flood aler
# 0.80  |  One killed  |  Three kill
# 3.20  |  Hassoun to  |  Mufti : co
# 4.80  |  Hong Kong   |  Hong Kong
# 4.20  |  Senate con  |  US Senate
# 2.20  |  Obama to m  |  Obama to m
# 1.00  |  Protests f  |  Scores 'ki
# 3.60  |  China yuan  |  China yuan
# 1.60  |  Israelis a  |  Israeli ar
# 3.00  |  Japanese p  |  Japan mayo
# 2.40  |  4 killed,   |  43 killed,
# 0.40  |  Iran backs  |  Iran says
# 0.00  |  Thai gover  |  Philippine
# 5.00  |  Colorado G  |  Colorado g
# 1.20  |  Pakistani   |  Pakistani
# 1.40  |  House blaz  |  US drone s
# 4.00  |  FAA lifts   |  FAA lifts
# 4.60  |  World's ol  |  Japan: Wor
# 3.40  |  Pakistanis  |  Pakistan h
# 0.40  |  Algeria pr  |  Bulgarian
# 0.00  |  Yemen: Fig  |  Janet Yell
# 4.80  |  Pakistan's  |  Pakistan's

# %% [markdown]
# All good!

# %%
examples = []

dev_s1 = []
dev_s2 = []
dev_scores = []

for row in rows:
    examples.append(
        InputExample(
            texts=[row[5].strip(), row[6].strip()],
            label=float(row[4])))
    
    dev_s1.append(row[5].strip())
    dev_s2.append(row[6].strip())
    dev_scores.append(float(row[4].strip()))

dev_dl = DataLoader(examples, shuffle=True, batch_size=batch_size)

# Because EmbeddingSimilarityEvaluator won't accept a DataLoader
dev_examples = {
      'sentences1': dev_s1
    , 'sentences2': dev_s2
    , 'scores': dev_scores }

# %%
# Should be 1500
len(examples)
# Out:
# 1500

# %% [markdown]
# ### Test set

# %%
with open(test_csv) as f:
    lines = f.readlines()
    lines = [l.strip() for l in lines]

# %%
# Should be 1379
len(lines)
# Out:
# 1379

# %%
rows = [l.split('\t') for l in lines]

# %%
row_type_counts = {}

for row in rows:
    if len(row) not in row_type_counts.keys():
        row_type_counts[len(row)] = 1
    else:
        row_type_counts[len(row)] += 1

row_type_counts
# Out:
# {7: 1095, 9: 284}

# %% [markdown]
# Assuming that the data is clean enough and the rows with 7 columns are all correctly filled, we will just quickly check the relevant columns of those with 9 fields, just to make sure our data is clean.

# %%
for row in rows:
    if len(row) == 9:
        print(f'{row[4][:10]}  |  {row[5][:10]}  |  {row[6][:10]}')
# Out:
# 3  |  I remained  |  I remained
# 3  |  In the US,  |  It really
# 0  |  There's al  |  There is a
# 0  |  You also i  |  You can do
# 2  |  I did this  |  I have thi
# 0  |  You just h  |  You may wa
# 5  |  You do not  |  You don't
# 3  |  You should  |  You should
# 2  |  You should  |  You should
# 0  |  You need t  |  You have t
# 2  |  It depends  |  i think it
# 5  |  You can do  |  Yes, you c
# 1  |  You should  |  You can do
# 4  |  You have t  |  You have t
# 4  |  I have few  |  I have two
# 1  |  You want t  |  You will h
# 1  |  if you don  |  The key th
# 1  |  Unfortunat  |  My answer
# 4  |  As soon as  |  Start them
# 1  |  You just h  |  It depends
# 5  |  The answer  |  The answer
# 4  |  To give th  |  I'll answe
# 4  |  Unfortunat  |  Sorry, I d
# 4  |  The rule -  |  I always g
# 4  |  This is no  |  This sound
# 3  |  Yes, it's   |  It's a goo
# 4  |  It probabl  |  It depends
# 0  |  It's not a  |  It's a goo
# 0  |  It's prett  |  It's much
# 1  |  Yes, there  |  Yes, that
# 4  |  Have you t  |  Have you t
# 5  |  You guys a  |  You are ma
# 2  |  You don't   |  You have n
# 4  |  There are   |  There are
# 0  |  Work into   |  It seems t
# 2  |  You can bu  |  You can bu
# 1  |  The coffee  |  One idea i
# 0  |  There are   |  There are
# 2  |  You might   |  My advice
# 5  |  It's not a  |  It is not
# 1  |  You just h  |  They can,
# 3  |  Yes, you s  |  Yes, you s
# 2  |  From what   |  Can you do
# 5  |  Take a loo  |  Take a loo
# 2  |  I'd say it  |  I'd say it
# 1  |  Some of wh  |  Not much y
# 5  |  This is no  |  But it is
# 0  |  The answer  |  You have a
# 5  |  I was in a  |  I had a si
# 5  |  I've had t  |  I had this
# 0  |  There is n  |  There is n
# 2  |  I am not s  |  I am not s
# 4  |  It depends  |  In other w
# 0  |  You need t  |  Yes, you s
# 2  |  You are no  |  No you are
# 3  |  It depends  |  I guess it
# 0  |  You just h  |  It is his
# 3  |  It depends  |  It depends
# 1  |  This is a   |  This is a
# 3  |  This is a   |  This sound
# 2  |  It very mu  |  I think it
# 4  |  I have the  |  I have had
# 0  |  No it does  |  No it is n
# 4  |  My answer   |  I think th
# 4  |  I don't th  |  I don't th
# 2  |  It depends  |  It depends
# 2  |  There's no  |  There's no
# 5  |  You answer  |  You have a
# 2  |  You just h  |  Th answer
# 2  |  This is no  |  This is pr
# 0  |  The best t  |  My recomme
# 2  |  I'd say it  |  I'd say it
# 0  |  You don't   |  You don't
# 2  |  I have the  |  I have the
# 4  |  It's not a  |  I do not t
# 4  |  You are on  |  You are ri
# 1  |  This doesn  |  This is a
# 4  |  How should  |  So how sho
# 4  |  Does this   |  Does this
# 2  |  You can us  |  You can st
# 2  |  It really   |  It depends
# 2  |  I've had t  |  I've had t
# 0  |  You need t  |  You should
# 3  |  It depends  |  It depends
# 1  |  Yes, you h  |  You are no
# 5  |  I don't se  |  I don't se
# 1  |  Hope this   |  If what yo
# 0  |  The best t  |  The best t
# 2  |  It depends  |  It depends
# 2  |  You just h  |  You have t
# 0  |  You PROBAB  |  Saying "th
# 3  |  It really   |  It doesn't
# 3  |  You don't   |  You don't
# 3  |  I think yo  |  I think yo
# 5  |  It makes a  |  No, it mak
# 5  |  I think it  |  I think it
# 4  |  I'm going   |  I'm going
# 1  |  You just h  |  Yes, you c
# 0  |  You should  |  You should
# 5  |  There's no  |  I'm afraid
# 0  |  What kind   |  What kind
# 4  |  It depends  |  I guess it
# 5  |  You answer  |  You've ans
# 3  |  I don't th  |  I don't th
# 3  |  There are   |  There are
# 3  |  This is th  |  Something
# 2  |  That's wha  |  Yes, I bel
# 1  |  If you are  |  If not, do
# 0  |  It's all i  |  It's all a
# 2  |  If you are  |  If you do
# 0  |  You need t  |  You have t
# 2  |  I would sa  |  Personally
# 5  |  Can you do  |  Can you do
# 3  |  Sure, I've  |  I've done
# 3  |  You can us  |  You can do
# 5  |  How do you  |  How to do
# 3  |  I've locat  |  I found so
# 2  |  I would sa  |  I would sa
# 1  |  Unfortunat  |  The answer
# 1  |  If you are  |  You don't,
# 5  |  It's also   |  It's defin
# 1  |  It's not a  |  It's a goo
# 2  |  This answe  |  This answe
# 4  |  There are   |  There are
# 0  |  You will w  |  You will a
# 2  |  It depends  |  It depends
# 1  |  There are   |  There are
# 3  |  You don't   |  Since you
# 1  |  Vietnamese  |  Nepalese c
# 1  |  It depends  |  It depends
# 5  |  I don't se  |  I don't se
# 5  |  There's no  |  I really d
# 5  |  You got it  |  Yes you go
# 0  |  You just h  |  Remember t
# 4  |  How do you  |  How should
# 4  |  I was in a  |  I am in a
# 0  |  What is yo  |  What is yo
# 0  |  You don't   |  You don't
# 2  |  That is yo  |  Work with
# 4  |  It depends  |  It's up to
# 5  |  There are   |  A couple t
# 3  |  It depends  |  It depends
# 3  |  The wood p  |  It's just
# 4  |  Well, I wo  |  I wouldn't
# 1  |  This is a   |  This is a
# 0  |  The answer  |  To directl
# 2  |  Yes, there  |  Valid reas
# 2  |  I think it  |  It depends
# 5  |  Can you do  |  So, CAN yo
# 4  |  I think th  |  I don't th
# 5  |  There are   |  There are
# 1  |  The key is  |  You may wa
# 0  |  You don't   |  You don't
# 2  |  I think yo  |  You've pre
# 0  |  There are   |  There are
# 2  |  You burn m  |  The more y
# 1  |  It depends  |  It depends
# 5  |  You got it  |  You've got
# 5  |  You answer  |  You pretty
# 3  |  I have the  |  I had the
# 0  |  Yes, there  |  Yes, there
# 0  |  They can b  |  Yes, altho
# 2  |  I would lo  |  I would lo
# 5  |  You are on  |  You're on
# 1  |  If you hav  |  You should
# 3  |  Yes it is   |  The simple
# 3  |  I don't th  |  I don't th
# 2  |  It looks t  |  It is up t
# 1  |  Problem is  |  The Joker
# 1  |  In the fir  |  So I don't
# 2  |  It is impo  |  It is diff
# 2  |  You need t  |  This gives
# 4  |  Work into   |  You work o
# 0  |  No, you do  |  You do not
# 1  |  Yes, it is  |  Yes, it is
# 1  |  You just h  |  So if that
# 2  |  Yes, you s  |  Yes, you s
# 2  |  I think it  |  I think th
# 0  |  You don't   |  Other than
# 1  |  Yes, there  |  There's no
# 5  |  What are y  |  What are y
# 2  |  I'm going   |  I'm going
# 2  |  If your lo  |  You do not
# 5  |  A few more  |  A few thin
# 2  |  Now you do  |  You don't
# 5  |  I'm afraid  |  I think th
# 0  |  It is more  |  Point is:
# 4  |  It varies   |  This varie
# 4  |  I have the  |  I have the
# 4  |  I have the  |  I have the
# 0  |  You are on  |  You're rig
# 2  |  Primer/pai  |  Nope that
# 2  |  The best t  |  The best t
# 5  |  It's also   |  It's mostl
# 2  |  I was in a  |  Personally
# 3  |  You can us  |  Yes, you c
# 4  |  You have t  |  You have t
# 1  |  It depends  |  It depends
# 5  |  I had the   |  I have jus
# 2  |  Sometime i  |  You could
# 1  |  You don't   |  They just
# 2  |  Also it is  |  It is impo
# 1  |  I think it  |  I think it
# 4  |  It's not a  |  No, it's n
# 5  |  I'm thinki  |  I think it
# 1  |  It depends  |  You need t
# 4  |  You have a  |  This is a
# 2  |  Unfortunat  |  If the con
# 4  |  Unfortunat  |  This canno
# 2  |  I would pe  |  I would re
# 4  |  I think th  |  I don't th
# 5  |  It's not a  |  Not a good
# 0  |  You don't   |  You don't
# 0  |  You have t  |  You're pro
# 5  |  I had the   |  I have exa
# 4  |  My answer   |  The answer
# 1  |  You should  |  You should
# 4  |  I had the   |  I had the
# 4  |  Hope this   |  Is this th
# 5  |  There are   |  I think th
# 5  |  It's prett  |  It is up t
# 4  |  There are   |  There are
# 1  |  The answer  |  The answer
# 0  |  It is impo  |  This is a
# 3  |  There are   |  There are
# 4  |  It depends  |  It depends
# 3  |  There are   |  There are
# 5  |  There are   |  There are
# 5  |  So think i  |  Think of i
# 5  |  Maybe this  |  Maybe this
# 1  |  It depends  |  They can,
# 0  |  Microwave   |  Your best
# 4  |  In the US,  |  This will
# 1  |  It's not a  |  It's not j
# 4  |  There are   |  There are
# 3  |  I've had t  |  I had this
# 5  |  This is no  |  Not a good
# 5  |  I realized  |  I know thi
# 0  |  Yes, there  |  Yes, there
# 1  |  Yes, there  |  To my know
# 0  |  You don't   |  You don't
# 0  |  There is n  |  There is n
# 0  |  Yes, you s  |  Yes, you s
# 0  |  You should  |  You don't
# 4  |  I've had t  |  I had this
# 5  |  You may ha  |  You have t
# 1  |  My answer   |  This is a
# 1  |  The key th  |  It really
# 4  |  Not a dire  |  Not a real
# 1  |  There are   |  There are
# 5  |  I agree wi  |  I agree wi
# 3  |  The answer  |  If the ans
# 5  |  It rather   |  That depen
# 5  |  This is a   |  This is a
# 2  |  US drone s  |  US drone s
# 5  |  Russian op  |  Russian Op
# 5  |  Senate con  |  Senate con
# 5  |  Israel con  |  Israel off
# 5  |  Jurors fin  |  Jodi Arias
# 4  |  Twitter re  |  Twitter sa
# 3  |  Goa buildi  |  Indian bui
# 3  |  Pak religi  |  CII endors
# 5  |  Mt Gox rev  |  Mt Gox fin
# 4  |  More than   |  Hundreds b
# 2  |  Redford to  |  Redford ad
# 1  |  Obama hold  |  UK urges c
# 4  |  South Kore  |  South Kore
# 0  |  Tycoon cla  |  Polling st
# 2  |  Syria agre  |  UK's Camer
# 5  |  AbbVie Sou  |  AbbVie coo
# 3  |  Militant a  |  Militant a
# 2  |  13 killed   |  6 killed i
# 2  |  Rev's Earl  |  Rev.'s Ear
# 0  |  Pope canon  |  Sweden rec
# 0  |  Funeral of  |  Funeral of
# 1  |  Waba emerg  |  Waiting fo
# 1  |  5 US airst  |  Kurds see
# 1  |  US Senate   |  US scienti
# 2  |  Editors fr  |  Media free
# 0  |  Philippine  |  Philippine
# 1  |  Israel bar  |  Two-state
# 1  |  How much d  |  Lawmakers
# 0  |  Obama Stru  |  Myanmar St
# 0  |  South Kore  |  North Kore

# %% [markdown]
# Everything seems OK. Let's just check the first 20 rows with 7 columns also.

# %%
for row in rows[:20]:
    if len(row) == 7:
        print(f'{row[4][:10]}  |  {row[5][:10]}  |  {row[6][:10]}')
# Out:
# 2.500  |  A girl is   |  A girl is
# 3.600  |  A group of  |  A group of
# 5.000  |  One woman   |  A woman me
# 4.200  |  A man is c  |  A man is s
# 1.500  |  A man is p  |  A man is p
# 1.800  |  A woman is  |  A woman is
# 3.500  |  A man is r  |  A man is r
# 2.200  |  A man is p  |  A man is p
# 2.200  |  A man is p  |  A lady is
# 1.714  |  A man is p  |  A man is p
# 1.714  |  A man is p  |  A man is p
# 5.000  |  A man is c  |  A man cuts
# 0.600  |  A man is c  |  A man is t
# 4.400  |  A man is s  |  A man is c
# 2.000  |  A man is s  |  A man is s
# 1.800  |  A man is p  |  A man is p
# 4.400  |  A baby pan  |  A panda sl
# 3.600  |  A man is s  |  A man is p
# 3.600  |  A man atta  |  A man slap
# 1.200  |  A man is d  |  A man is r

# %% [markdown]
# All good!

# %%
examples = []

test_s1 = []
test_s2 = []
test_scores = []

for row in rows:
    examples.append(
        InputExample(
            texts=[row[5].strip(), row[6].strip()],
            label=float(row[4])))
    
    test_s1.append(row[5].strip())
    test_s2.append(row[6].strip())
    test_scores.append(float(row[4].strip()))

test_dl = DataLoader(examples, shuffle=True, batch_size=batch_size)

# Because EmbeddingSimilarityEvaluator won't accept a DataLoader
test_examples = {
      'sentences1': test_s1
    , 'sentences2': test_s2
    , 'scores': test_scores }

# %%
# Should be 1379
len(examples)
# Out:
# 1379

# %% [markdown]
# # Model

# %%
model_name = f'S-BERT-STS-Trained-batch_size-{batch_size}-epochs-{epochs}-warmup_steps-{warmup_steps}'
model_path = 'models' + '/' + model_name

# %% [markdown]
# Either build a model...

# %%
# word_embedding_model = Transformer('bert-base-uncased')  # [optional] max_seq_length=256
# mean_pooling = Pooling(word_embedding_model.get_word_embedding_dimension(), pooling_mode='mean')
# model = SentenceTransformer(modules=[word_embedding_model, mean_pooling])
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ... or load a previously saved one from disk.

# %%
model = SentenceTransformer(model_path)

# %% [markdown]
# # Training

# %% [markdown]
# ### S-BERT Regression Objective

# %% [markdown]
# Documentation for the Cosine Similarity Loss:
# https://www.sbert.net/docs/package_reference/losses.html#sentence_transformers.losses.CosineSimilarityLoss
#
# The loss that will be minimized is the following:
#
# $$ \mathrm{Loss} = \lVert  \,\,  \mathrm{input \, label} - \mathrm{cos\_score\_transformation} \, ( \, \mathrm{cosine\_sim} \, (u,v) \,)  \,\,  \rVert_2 $$

# %% [markdown]
# The similarity score in the STS benchmark goes from 0 to 5, while cosine similarity goes from -1 to 1.
# We need to therefore map the cosine similarity score back to the 0-5 range.

# %%
class ScoreMap(nn.Module):
    def __init__(self, *args, **kwargs):
        super(ScoreMap, self).__init__()

    def forward(self, input: Tensor) -> Tensor:
        """Maps input from [-1, 1] to [0, 5]."""
        return 5/2 * input + 5/2

# %%
train_loss = CosineSimilarityLoss(
                 model=model,
                 loss_fct=nn.MSELoss(),
                 cos_score_transformation=ScoreMap())

# %% [markdown]
# ### Model Training (Fine-Tuning)

# %% [markdown]
# Not necessary to call `fit()`, if you've loaded a fine-tuned model.

# %%
# model.fit(train_objectives=[(train_dl, train_loss)],
#           epochs=epochs,
#           warmup_steps=warmup_steps)

# %% [markdown]
# Save the model to disk for later use if you want.

# %%
# model.save(path=model_path, model_name=model_name, create_model_card=True)

# %%
dev_evaluator = EmbeddingSimilarityEvaluator(
    sentences1=dev_examples['sentences1'],
    sentences2=dev_examples['sentences2'],
    scores=dev_examples['scores'],
    batch_size=batch_size,
    main_similarity=SimilarityFunction.COSINE,  # {COSINE, EUCLIDEAN, MANHATTAN, DOT_PRODUCT}
    show_progress_bar=True,
    write_csv=False)

# The SimilarityFunction values come from:
# https://github.com/UKPLab/sentence-transformers/blob/46a149433fe9af0851f7fa6f9bf37b5ffa2c891c/sentence_transformers/evaluation/EmbeddingSimilarityEvaluator.py#L120

# %% [markdown]
# ### Evaluation: Spearman Rank Correlation on Dev Set

# %% [markdown]
# In order to obtain the embeddings necessary for the evaluation, the model will run over the data twice: once for the first sentences, and once for the second sentences.

# %%
dev_spearman_rho = model.evaluate(dev_evaluator)
print(f'Spearman (dev set): {dev_spearman_rho * 100}')  # For consistency with the paper
# Out:
# Spearman (dev set): 73.03830917146799

# %% [markdown]
# # Final Evaluation

# %% [markdown]
# ### Spearman Rank Correlation on Test Set

# %%
test_evaluator = EmbeddingSimilarityEvaluator(
    sentences1=test_examples['sentences1'],
    sentences2=test_examples['sentences2'],
    scores=test_examples['scores'],
    batch_size=batch_size,
    main_similarity=SimilarityFunction.COSINE,  # {COSINE, EUCLIDEAN, MANHATTAN, DOT_PRODUCT}
    show_progress_bar=True,
    write_csv=False)

# The SimilarityFunction values come from:
# https://github.com/UKPLab/sentence-transformers/blob/46a149433fe9af0851f7fa6f9bf37b5ffa2c891c/sentence_transformers/evaluation/EmbeddingSimilarityEvaluator.py#L120

# %%
test_spearman_rho = model.evaluate(test_evaluator)
print(f'Spearman (test set): {test_spearman_rho * 100}')  # For consistency with the paper
# Out:
# Spearman (test set): 65.57546300121835

# %% [markdown]
# # Conclusion

# %% [markdown]
# All else being equal, for `batch_size` in {16, 32}, we have the following Spearman scores:
#  - dev set: {73.03830917146799, 72.19737929737312}
#  - test set: {65.57546300121835, 64.55123444928913}
